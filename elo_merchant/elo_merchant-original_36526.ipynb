# %%
# %reset -f

import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sns
import csv
import re
import sys, os, random

from datetime import datetime

from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import PolynomialFeatures

from sklearn.model_selection import GridSearchCV

#sys.path.insert(0, "/Users/schwalmdaniel/github/xgboost/python-package")
sys.path.insert(0, "e:/xgboost/python-package")
from xgboost import XGBRegressor
import xgboost as xgb
from xgboost import plot_importance

from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error

from matplotlib import pyplot
# %matplotlib inline

# reproducible results
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(37)
random.seed(17)

pd.set_option('display.max_rows',1000)

def _get_xgb_feat_importances(clf, feature_names):

        try:
            # Handles case when clf has been created by calling
            # xgb.XGBClassifier.fit() or xgb.XGBRegressor().fit()
            fscore = clf.get_booster().get_fscore()
        except:
            # Handles case when clf has been created by calling xgb.train.
            # Thus, clf is an instance of xgb.Booster.
            fscore = clf.get_fscore()

        trained_feature_names = feature_names #self._get_trained_feature_names()

        feat_importances = []
        
        #print(fscore.items())

        features = {}
        
        for k, v in fscore.items():
            features[k] = v
            
        return sorted(features.items(), key=lambda x: x[1])[-100:]

def rmse_cv(model, train,y):
    n_folds = 5
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
    rmse= np.sqrt(-cross_val_score(model, train.values, y, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

def convertToOrdinal(df,colname,mapping,targetDf,targetColname,dropOriginalCol = True):
    mostFrequent = df[colname].value_counts().index[0]
    df[colname].fillna(mostFrequent,inplace=True)
    targetDf[targetColname] = df[colname].apply(lambda x: mapping[x])
    if dropOriginalCol:
        targetDf = df.drop([colname],axis=1) 
        
def extractDateFeatures(df, sourceName):
    seasons = [0,0,1,1,1,2,2,2,3,3,3,0] #dec - feb is winter, then spring, summer, fall etc
    df['df_temp_' + sourceName] = df[sourceName].apply(lambda x: (datetime.strptime(x, "%Y-%m-%d %H:%M:%S" )))
    df['df_year_' + sourceName] = pd.to_datetime(df[sourceName]).dt.year.astype('uint16')
    df['df_quarter_' + sourceName] = df['df_temp_' + sourceName].apply(lambda x: x.month-1//3 + 1)
    df['df_yearmonth_' + sourceName] = df['df_temp_' + sourceName].apply(lambda x: int(str(x.year) + str(x.month)) )
    df['df_month_' + sourceName] = pd.to_datetime(df[sourceName]).dt.month.astype('uint8')
    df['df_weekofyear_' + sourceName] = pd.to_datetime(df[sourceName]).dt.weekofyear.astype('uint8')
    df['df_day_' + sourceName] = pd.to_datetime(df[sourceName]).dt.day.astype('uint8')
    df['df_weekday_' + sourceName] = pd.to_datetime(df[sourceName]).dt.dayofweek.astype('uint8')
    df['df_weekend_' + sourceName] = (df['df_weekday_' + sourceName] >=5).astype('uint8') # new
    df['df_hour_' + sourceName] = pd.to_datetime(df[sourceName]).dt.hour.astype('uint8')
    df['df_season_' + sourceName] = df['df_temp_' + sourceName].apply(lambda x: seasons[x.month-1])
    
    df['df_season_' + sourceName]      = df['df_season_' + sourceName].astype('uint8')
    df['df_quarter_' + sourceName]      = df['df_quarter_' + sourceName].astype('uint8') 
    df['df_yearmonth_' + sourceName]      = df['df_yearmonth_' + sourceName].astype('uint32') 

#root = '/Users/schwalmdaniel/github/kaggle/house_prices_kaggle'
root = 'e:/kaggle/elo_merchant'

train=pd.read_csv(root + "/train.csv")
test=pd.read_csv(root + "/test.csv")
merchants=pd.read_csv(root + "/merchants.csv")
#new_tr=pd.read_csv(root + "/new_merchant_transactions.csv")
new_tr=pd.read_csv(root + "/new_tr.csv")
#hist_tr=pd.read_csv(root + "/historical_transactions.csv")
hist_tr=pd.read_csv(root + "/hist_tr.csv")

test.fillna('2017-06',inplace=True)
train = train.dropna()

train['first_active_month'] = train['first_active_month'].apply(lambda x : str(x) + '-01').astype(str)
test['first_active_month'] = test['first_active_month'].apply(lambda x : str(x) + '-01').astype(str)

# have a look at the ds

new_tr.head()
# Out:
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_415bb3a509      107          N             1
# 1               Y  C_ID_415bb3a509      140          N             1
# 2               Y  C_ID_415bb3a509      330          N             1
# 3               Y  C_ID_415bb3a509       -1          Y             1
# 4               Y  C_ID_ef55cf8d4b       -1          Y             1
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          B                   307  M_ID_b0c793002c          1
# 1          B                   307  M_ID_88920c89e8          1
# 2          B                   507  M_ID_ad5237ef6b          2
# 3          B                   661  M_ID_9e84cda3b1          1
# 4          B                   166  M_ID_3c86fa3831          1
#
#    purchase_amount           ...            df_year_purchase_date  \
# 0        -0.557574           ...                             2018
# 1        -0.569580           ...                             2018
# 2        -0.551037           ...                             2018
# 3        -0.671926           ...                             2018
# 4        -0.659904           ...                             2018
#
#    df_quarter_purchase_date  df_yearmonth_purchase_date  \
# 0                         4                       20183
# 1                         4                       20183
# 2                         5                       20184
# 3                         4                       20183
# 4                         4                       20183
#
#    df_month_purchase_date  df_weekofyear_purchase_date  df_day_purchase_date  \
# 0                       3                           10                    11
# 1                       3                           12                    19
# 2                       4                           17                    26
# 3                       3                           10                     7
# 4                       3                           12                    22
#
#    df_weekday_purchase_date  df_weekend_purchase_date  df_hour_purchase_date  \
# 0                         6                         1                     14
# 1                         0                         0                     18
# 2                         3                         0                     14
# 3                         2                         0                      9
# 4                         3                         0                     21
#
#    df_season_purchase_date
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
#
# [5 rows x 24 columns]

# %%
merchants = merchants.drop(['city_id','state_id','merchant_category_id','subsector_id','category_2'],axis=1,errors='ignore')

# %% [raw]
# merchants.dtypes

# %% [raw]
# new_tr=pd.read_csv(root + "/new_tr.csv")

# %%
new_tr = new_tr.merge(merchants,on=['merchant_id'],how='left',suffixes=('','_mcts'))
hist_tr = hist_tr.merge(merchants,on=['merchant_id'],how='left',suffixes=('','_mcts'))
new_tr.head()
# Out:
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_415bb3a509      107          N             1
# 1               Y  C_ID_415bb3a509      140          N             1
# 2               Y  C_ID_415bb3a509      330          N             1
# 3               Y  C_ID_415bb3a509       -1          Y             1
# 4               Y  C_ID_ef55cf8d4b       -1          Y             1
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          B                   307  M_ID_b0c793002c          1
# 1          B                   307  M_ID_88920c89e8          1
# 2          B                   507  M_ID_ad5237ef6b          2
# 3          B                   661  M_ID_9e84cda3b1          1
# 4          B                   166  M_ID_3c86fa3831          1
#
#    purchase_amount     ...     avg_sales_lag3  avg_purchases_lag3  \
# 0        -0.557574     ...               0.84            1.055253
# 1        -0.569580     ...               1.14            1.081037
# 2        -0.551037     ...               1.05            1.055359
# 3        -0.671926     ...               1.16            1.248691
# 4        -0.659904     ...               0.77            0.815580
#
#    active_months_lag3  avg_sales_lag6  avg_purchases_lag6  active_months_lag6  \
# 0                 3.0            0.82            1.158625                 6.0
# 1                 3.0            1.13            1.088138                 6.0
# 2                 3.0            1.03            1.055851                 6.0
# 3                 3.0            1.11            1.177485                 6.0
# 4                 3.0            0.68            0.653999                 6.0
#
#    avg_sales_lag12  avg_purchases_lag12  active_months_lag12  category_4
# 0             0.81             1.235863                 12.0           N
# 1             1.13             1.102611                 12.0           N
# 2             1.05             1.063897                 12.0           N
# 3             1.04             1.066582                 12.0           Y
# 4             0.47             0.414029                 12.0           Y
#
# [5 rows x 40 columns]

# %%
for df in [new_tr,hist_tr]:
    df['category_1_mcts'].fillna('N',inplace=True)
    df['active_months_lag3'].fillna((df['active_months_lag3'].mean()), inplace=True)
    df['active_months_lag6'].fillna((df['active_months_lag6'].mean()), inplace=True)
    df['active_months_lag12'].fillna((df['active_months_lag12'].mean()), inplace=True)
    df['avg_sales_lag3'].fillna((df['avg_sales_lag3'].mean()), inplace=True)
    df['avg_sales_lag6'].fillna((df['avg_sales_lag6'].mean()), inplace=True)
    df['avg_sales_lag12'].fillna((df['avg_sales_lag12'].mean()), inplace=True)
    df['avg_purchases_lag3'].fillna((df['avg_purchases_lag3'].mean()), inplace=True)
    df['avg_purchases_lag6'].fillna((df['avg_purchases_lag6'].mean()), inplace=True)
    df['avg_purchases_lag12'].fillna((df['avg_purchases_lag12'].mean()), inplace=True)
    df['numerical_1'].fillna((df['numerical_1'].mean()), inplace=True)
    df['numerical_2'].fillna((df['numerical_2'].mean()), inplace=True)

# %%
new_tr.avg_sales_lag3.describe()
# Out:
# count    1.994895e+06
# mean     4.312295e+01
# std      5.889685e+03
# min      3.300000e-01
# 25%      9.500000e-01
# 50%      1.020000e+00
# 75%      1.100000e+00
# max      8.518446e+05
# Name: avg_sales_lag3, dtype: float64

# %%
# reducing memory footprint
for df in [new_tr,hist_tr]:
    df['state_id'] = df['state_id'].astype('int8')
    df['city_id'] = df['city_id'].astype('int16')
    df['installments'] = df['installments'].astype('int16')
    df['merchant_category_id'] = df['merchant_category_id'].astype('int16')
    df['month_lag'] = df['month_lag'].astype('uint8')
    df['subsector_id'] = df['subsector_id'].astype('int8')
    df['df_year_purchase_date'] = df['df_year_purchase_date'].astype('uint16')
    df['df_quarter_purchase_date'] = df['df_quarter_purchase_date'].astype('uint8')
    df['df_yearmonth_purchase_date'] = df['df_yearmonth_purchase_date'].astype('uint16')
    df['df_month_purchase_date'] = df['df_month_purchase_date'].astype('uint8')
    df['df_day_purchase_date'] = df['df_day_purchase_date'].astype('uint8')
    df['df_weekday_purchase_date'] = df['df_weekday_purchase_date'].astype('uint8')
    df['df_hour_purchase_date'] = df['df_hour_purchase_date'].astype('uint8')
    df['df_season_purchase_date'] = df['df_season_purchase_date'].astype('uint8')
    df['category_2'] = df['category_2'].astype('float16')
    df['active_months_lag3'] = df['active_months_lag3'].astype('uint8')
    df['active_months_lag6'] = df['active_months_lag6'].astype('uint8')
    df['active_months_lag12'] = df['active_months_lag12'].astype('uint8')

# %% [raw]
# new_tr.dtypes

# %% [raw]
# new_tr.category_1_mcts.fillna('N',inplace=True)

# %% [raw]
# new_tr.category_2_mcts.isna().sum()

# %%
for df in [new_tr,hist_tr]:
    df['orig_state_id'] = df['state_id']
    df['orig_subsector_id'] = df['subsector_id']
    #df['orig_category_2'] = df['category_2']
    #df['orig_category_3'] = df['category_3']
    df['category_1'] = df['category_1'].map({'Y': 1, 'N': 0})
    df['category_1_mcts'] = df['category_1_mcts'].map({'Y': 1, 'N': 0})
    df['authorized_flag'] = df['authorized_flag'].map({'Y': 1, 'N': 0})
    df = pd.get_dummies(df, 
        columns = ['state_id','subsector_id'
                   ,'most_recent_sales_range','most_recent_purchases_range','category_4']
                        ,prefix_sep='_dummy_')
    df['state_id'] = df['orig_state_id']
    df['subsector_id'] = df['orig_subsector_id']
    #df['category_2'] = df['orig_category_2']
    #df['category_3'] = df['orig_category_3']
    df = df.drop(['orig_state_id','orig_subsector_id','orig_category_2','orig_category_3'],axis=1,errors='ignore')
    df.head()

# %% [raw]
# hist_tr['orig_state_id'] = hist_tr['state_id']
# hist_tr['orig_subsector_id'] = hist_tr['subsector_id']
# #hist_tr['orig_category_2'] = hist_tr['category_2']
# #hist_tr['orig_category_3'] = hist_tr['category_3']
# hist_tr['category_1'] = hist_tr['category_1'].map({'Y': 1, 'N': 0})
# hist_tr['category_1_mcts'] = hist_tr['category_1_mcts'].map({'Y': 1, 'N': 0})
# hist_tr['authorized_flag'] = hist_tr['authorized_flag'].map({'Y': 1, 'N': 0})
# hist_tr = pd.get_dummies(hist_tr,
#     columns = ['state_id','subsector_id','most_recent_sales_range',
#                'most_recent_purchases_range','category_4'],prefix_sep='_dummy_')
# hist_tr['state_id'] = hist_tr['orig_state_id']
# hist_tr['subsector_id'] = hist_tr['orig_subsector_id']
# #hist_tr['category_2'] = hist_tr['orig_category_2']
# #hist_tr['category_3'] = hist_tr['orig_category_3']
# hist_tr = hist_tr.drop(['orig_state_id','orig_subsector_id','orig_category_2','orig_category_3','category_2'],axis=1,errors='ignore')
# hist_tr.head()

# %%
today = datetime.now()
train['active_since_months'] = train['first_active_month'].apply(lambda x : (today - datetime.strptime(x,'%Y-%m-%d')).days)
test['active_since_months'] = test['first_active_month'].apply(lambda x : (today - datetime.strptime(x,'%Y-%m-%d')).days)

# %% [raw]
# merchants.head()

# %% [raw]
# new_tr.merchant_id.describe()

# %% [raw]
# X.dtypes

# %% [raw]
# extractDateFeatures(new_tr,'purchase_date')
# extractDateFeatures(hist_tr,'purchase_date')

# %% [raw]
# hist_tr.head()

# %% [raw]
# new_tr = new_tr.drop(['df_temp_purchase_date'],axis=1,errors='ignore')
# hist_tr = hist_tr.drop(['df_temp_purchase_date'],axis=1,errors='ignore')

# %% [raw]
# new_tr.to_csv(root + '/new_tr.csv', index=False)
# hist_tr.to_csv(root + '/hist_tr.csv', index=False)

# %%
num_aggregations = {
    'authorized_flag': ['sum','mean'],
    'city_id': ['count','nunique'],
    'purchase_date': [np.ptp,'min','max'],
    'purchase_amount': ['min','max','var','sum','mean','std'],
    'installments': ['min','max','var','sum','mean','std'],
    'month_lag': ['min','max','var','sum','mean','std'],
    'state_id': ['count','nunique'],
    'subsector_id': ['count','nunique'],
    'merchant_category_id': ['count','nunique'],
    'category_1': ['count','nunique','sum','mean'],
    'category_2': ['count','nunique'],
    'category_3': ['count','nunique'],
    'merchant_id': ['count','nunique'],
    'df_season_purchase_date': ['min','max','var','mean','std','count','nunique'],
    'df_hour_purchase_date': ['min','max','var','mean','std','count','nunique'],
    'df_year_purchase_date': ['min','max','var','mean','std','count','nunique'],
    'df_quarter_purchase_date': ['min','max','var','mean','std','count','nunique'],
    'df_yearmonth_purchase_date': ['min','max','var','mean','std','count','nunique'],
    'df_month_purchase_date': ['min','max','var','mean','std','count','nunique'],
    'df_day_purchase_date': ['min','max','var','mean','std','count','nunique'],
    'df_weekday_purchase_date': ['min','max','var','mean','std','count','nunique'],
    'merchant_group_id': ['count','nunique'],
    'numerical_1': ['mean'],
    'numerical_2': ['mean'],
    'category_1_mcts': ['count','nunique','sum','mean'],
    'avg_sales_lag3': ['mean'],
    'avg_purchases_lag3': ['mean'],
    'active_months_lag3': ['mean'],
    'avg_sales_lag6': ['mean'],
    'avg_purchases_lag6': ['mean'],
    'active_months_lag6': ['mean'],
    'avg_sales_lag12': ['mean'],
    'avg_purchases_lag12': ['mean'],
    'active_months_lag12': ['mean'],
    'df_weekofyear_purchase_date': ['min','max','var','mean','std','count','nunique'],
    'df_weekend_purchase_date': ['min','max','var','mean','std','count','nunique'],
}

cardcols = [x for x in new_tr.columns.tolist() if 'dummy' in x ]
for col in cardcols:
    num_aggregations[col] = ['sum']
#print(num_aggregations)

# %% [raw]
# hist_tr.dtypes

# %%
hist_tr.loc[:, 'purchase_date'] = pd.DatetimeIndex(hist_tr['purchase_date']).astype(np.int64) * 1e-9
new_tr.loc[:, 'purchase_date'] = pd.DatetimeIndex(new_tr['purchase_date']).astype(np.int64) * 1e-9

new_tr_groups = new_tr.groupby('card_id').agg({**num_aggregations})
new_tr_groups.columns = pd.Index(['card_id_' + e[0] + "_" + e[1].upper() for e in new_tr_groups.columns.tolist()])

hist_tr_groups = hist_tr.groupby('card_id').agg({**num_aggregations})
hist_tr_groups.columns = pd.Index(['hcard_id_' + e[0] + "_" + e[1].upper() for e in hist_tr_groups.columns.tolist()])

train=train.join(new_tr_groups,on='card_id', how='left')
test=test.join(new_tr_groups,on='card_id', how='left')
train=train.join(hist_tr_groups,on='card_id', how='left')
test=test.join(hist_tr_groups,on='card_id', how='left')

del new_tr_groups
del hist_tr_groups

#train = pd.get_dummies(train,columns = ['feature_1','feature_2'],prefix_sep='___')
#test = pd.get_dummies(test,columns = ['feature_1','feature_2'],prefix_sep='___')

train.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557          5          2          1
# 1         2017-01-01  C_ID_3d0044924f          4          1          0
# 2         2016-08-01  C_ID_d639edf6cd          2          2          0
# 3         2017-09-01  C_ID_186d6a6901          4          3          0
# 4         2017-11-01  C_ID_cdbd2c0db2          1          3          0
#
#      target  active_since_months  card_id_authorized_flag_SUM  \
# 0 -0.820283                  563                         23.0
# 1  0.392913                  714                          6.0
# 2  0.688056                  867                          1.0
# 3  0.142495                  471                          7.0
# 4 -0.159749                  410                         36.0
#
#    card_id_authorized_flag_MEAN  card_id_city_id_COUNT  \
# 0                           1.0                   23.0
# 1                           1.0                    6.0
# 2                           1.0                    1.0
# 3                           1.0                    7.0
# 4                           1.0                   36.0
#
#                      ...                      \
# 0                    ...
# 1                    ...
# 2                    ...
# 3                    ...
# 4                    ...
#
#    hcard_id_df_weekofyear_purchase_date_STD  \
# 0                                 15.304703
# 1                                 16.801198
# 2                                 13.833253
# 3                                 17.127735
# 4                                 21.691493
#
#    hcard_id_df_weekofyear_purchase_date_COUNT  \
# 0                                         265
# 1                                         365
# 2                                          44
# 3                                          89
# 4                                         142
#
#    hcard_id_df_weekofyear_purchase_date_NUNIQUE  \
# 0                                            35
# 1                                            50
# 2                                            22
# 3                                            20
# 4                                            17
#
#    hcard_id_df_weekend_purchase_date_MIN  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
#
#    hcard_id_df_weekend_purchase_date_MAX  \
# 0                                      1
# 1                                      1
# 2                                      1
# 3                                      1
# 4                                      1
#
#    hcard_id_df_weekend_purchase_date_VAR  \
# 0                               0.229760
# 1                               0.238943
# 2                               0.191860
# 3                               0.126149
# 4                               0.209769
#
#    hcard_id_df_weekend_purchase_date_MEAN  \
# 0                                0.354717
# 1                                0.391781
# 2                                0.250000
# 3                                0.146067
# 4                                0.295775
#
#    hcard_id_df_weekend_purchase_date_STD  \
# 0                               0.479333
# 1                               0.488818
# 2                               0.438019
# 3                               0.355175
# 4                               0.458006
#
#    hcard_id_df_weekend_purchase_date_COUNT  \
# 0                                      265
# 1                                      365
# 2                                       44
# 3                                       89
# 4                                      142
#
#    hcard_id_df_weekend_purchase_date_NUNIQUE
# 0                                          2
# 1                                          2
# 2                                          2
# 3                                          2
# 4                                          2
#
# [5 rows x 263 columns]

# %%
train.dtypes
# Out:
# first_active_month                               object
# card_id                                          object
# feature_1                                         int64
# feature_2                                         int64
# feature_3                                         int64
# target                                          float64
# active_since_months                               int64
# card_id_authorized_flag_SUM                     float64
# card_id_authorized_flag_MEAN                    float64
# card_id_city_id_COUNT                           float64
# card_id_city_id_NUNIQUE                         float64
# card_id_purchase_date_PTP                       float64
# card_id_purchase_date_MIN                       float64
# card_id_purchase_date_MAX                       float64
# card_id_purchase_amount_MIN                     float64
# card_id_purchase_amount_MAX                     float64
# card_id_purchase_amount_VAR                     float64
# card_id_purchase_amount_SUM                     float64
# card_id_purchase_amount_MEAN                    float64
# card_id_purchase_amount_STD                     float64
# card_id_installments_MIN                        float64
# card_id_installments_MAX                        float64
# card_id_installments_VAR                        float64
# card_id_installments_SUM                        float64
# card_id_installments_MEAN                       float64
# card_id_installments_STD                        float64
# card_id_month_lag_MIN                           float64
# card_id_month_lag_MAX                           float64
# card_id_month_lag_VAR                           float64
# card_id_month_lag_SUM                           float64
# card_id_month_lag_MEAN                          float64
# card_id_month_lag_STD                           float64
# card_id_state_id_COUNT                          float64
# card_id_state_id_NUNIQUE                        float64
# card_id_subsector_id_COUNT                      float64
# card_id_subsector_id_NUNIQUE                    float64
# card_id_merchant_category_id_COUNT              float64
# card_id_merchant_category_id_NUNIQUE            float64
# card_id_category_1_COUNT                        float64
# card_id_category_1_NUNIQUE                      float64
# card_id_category_1_SUM                          float64
# card_id_category_1_MEAN                         float64
# card_id_category_2_COUNT                        float64
# card_id_category_2_NUNIQUE                      float64
# card_id_category_3_COUNT                        float64
# card_id_category_3_NUNIQUE                      float64
# card_id_merchant_id_COUNT                       float64
# card_id_merchant_id_NUNIQUE                     float64
# card_id_df_season_purchase_date_MIN             float64
# card_id_df_season_purchase_date_MAX             float64
# card_id_df_season_purchase_date_VAR             float64
# card_id_df_season_purchase_date_MEAN            float64
# card_id_df_season_purchase_date_STD             float64
# card_id_df_season_purchase_date_COUNT           float64
# card_id_df_season_purchase_date_NUNIQUE         float64
# card_id_df_hour_purchase_date_MIN               float64
# card_id_df_hour_purchase_date_MAX               float64
# card_id_df_hour_purchase_date_VAR               float64
# card_id_df_hour_purchase_date_MEAN              float64
# card_id_df_hour_purchase_date_STD               float64
# card_id_df_hour_purchase_date_COUNT             float64
# card_id_df_hour_purchase_date_NUNIQUE           float64
# card_id_df_year_purchase_date_MIN               float64
# card_id_df_year_purchase_date_MAX               float64
# card_id_df_year_purchase_date_VAR               float64
# card_id_df_year_purchase_date_MEAN              float64
# card_id_df_year_purchase_date_STD               float64
# card_id_df_year_purchase_date_COUNT             float64
# card_id_df_year_purchase_date_NUNIQUE           float64
# card_id_df_quarter_purchase_date_MIN            float64
# card_id_df_quarter_purchase_date_MAX            float64
# card_id_df_quarter_purchase_date_VAR            float64
# card_id_df_quarter_purchase_date_MEAN           float64
# card_id_df_quarter_purchase_date_STD            float64
# card_id_df_quarter_purchase_date_COUNT          float64
# card_id_df_quarter_purchase_date_NUNIQUE        float64
# card_id_df_yearmonth_purchase_date_MIN          float64
# card_id_df_yearmonth_purchase_date_MAX          float64
# card_id_df_yearmonth_purchase_date_VAR          float64
# card_id_df_yearmonth_purchase_date_MEAN         float64
# card_id_df_yearmonth_purchase_date_STD          float64
# card_id_df_yearmonth_purchase_date_COUNT        float64
# card_id_df_yearmonth_purchase_date_NUNIQUE      float64
# card_id_df_month_purchase_date_MIN              float64
# card_id_df_month_purchase_date_MAX              float64
# card_id_df_month_purchase_date_VAR              float64
# card_id_df_month_purchase_date_MEAN             float64
# card_id_df_month_purchase_date_STD              float64
# card_id_df_month_purchase_date_COUNT            float64
# card_id_df_month_purchase_date_NUNIQUE          float64
# card_id_df_day_purchase_date_MIN                float64
# card_id_df_day_purchase_date_MAX                float64
# card_id_df_day_purchase_date_VAR                float64
# card_id_df_day_purchase_date_MEAN               float64
# card_id_df_day_purchase_date_STD                float64
# card_id_df_day_purchase_date_COUNT              float64
# card_id_df_day_purchase_date_NUNIQUE            float64
# card_id_df_weekday_purchase_date_MIN            float64
# card_id_df_weekday_purchase_date_MAX            float64
# card_id_df_weekday_purchase_date_VAR            float64
# card_id_df_weekday_purchase_date_MEAN           float64
# card_id_df_weekday_purchase_date_STD            float64
# card_id_df_weekday_purchase_date_COUNT          float64
# card_id_df_weekday_purchase_date_NUNIQUE        float64
# card_id_merchant_group_id_COUNT                 float64
# card_id_merchant_group_id_NUNIQUE               float64
# card_id_numerical_1_MEAN                        float64
# card_id_numerical_2_MEAN                        float64
# card_id_category_1_mcts_COUNT                   float64
# card_id_category_1_mcts_NUNIQUE                 float64
# card_id_category_1_mcts_SUM                     float64
# card_id_category_1_mcts_MEAN                    float64
# card_id_avg_sales_lag3_MEAN                     float64
# card_id_avg_purchases_lag3_MEAN                 float64
# card_id_active_months_lag3_MEAN                 float64
# card_id_avg_sales_lag6_MEAN                     float64
# card_id_avg_purchases_lag6_MEAN                 float64
# card_id_active_months_lag6_MEAN                 float64
# card_id_avg_sales_lag12_MEAN                    float64
# card_id_avg_purchases_lag12_MEAN                float64
# card_id_active_months_lag12_MEAN                float64
# card_id_df_weekofyear_purchase_date_MIN         float64
# card_id_df_weekofyear_purchase_date_MAX         float64
# card_id_df_weekofyear_purchase_date_VAR         float64
# card_id_df_weekofyear_purchase_date_MEAN        float64
# card_id_df_weekofyear_purchase_date_STD         float64
# card_id_df_weekofyear_purchase_date_COUNT       float64
# card_id_df_weekofyear_purchase_date_NUNIQUE     float64
# card_id_df_weekend_purchase_date_MIN            float64
# card_id_df_weekend_purchase_date_MAX            float64
# card_id_df_weekend_purchase_date_VAR            float64
# card_id_df_weekend_purchase_date_MEAN           float64
# card_id_df_weekend_purchase_date_STD            float64
# card_id_df_weekend_purchase_date_COUNT          float64
# card_id_df_weekend_purchase_date_NUNIQUE        float64
# hcard_id_authorized_flag_SUM                      int64
# hcard_id_authorized_flag_MEAN                   float64
# hcard_id_city_id_COUNT                            int64
# hcard_id_city_id_NUNIQUE                          int64
# hcard_id_purchase_date_PTP                      float64
# hcard_id_purchase_date_MIN                      float64
# hcard_id_purchase_date_MAX                      float64
# hcard_id_purchase_amount_MIN                    float64
# hcard_id_purchase_amount_MAX                    float64
# hcard_id_purchase_amount_VAR                    float64
# hcard_id_purchase_amount_SUM                    float64
# hcard_id_purchase_amount_MEAN                   float64
# hcard_id_purchase_amount_STD                    float64
# hcard_id_installments_MIN                         int16
# hcard_id_installments_MAX                         int16
# hcard_id_installments_VAR                       float64
# hcard_id_installments_SUM                         int16
# hcard_id_installments_MEAN                      float64
# hcard_id_installments_STD                       float64
# hcard_id_month_lag_MIN                            uint8
# hcard_id_month_lag_MAX                            uint8
# hcard_id_month_lag_VAR                          float64
# hcard_id_month_lag_SUM                          float64
# hcard_id_month_lag_MEAN                         float64
# hcard_id_month_lag_STD                          float64
# hcard_id_state_id_COUNT                           int64
# hcard_id_state_id_NUNIQUE                         int64
# hcard_id_subsector_id_COUNT                       int64
# hcard_id_subsector_id_NUNIQUE                     int64
# hcard_id_merchant_category_id_COUNT               int64
# hcard_id_merchant_category_id_NUNIQUE             int64
# hcard_id_category_1_COUNT                         int64
# hcard_id_category_1_NUNIQUE                       int64
# hcard_id_category_1_SUM                           int64
# hcard_id_category_1_MEAN                        float64
# hcard_id_category_2_COUNT                         int64
# hcard_id_category_2_NUNIQUE                       int64
# hcard_id_category_3_COUNT                         int64
# hcard_id_category_3_NUNIQUE                       int64
# hcard_id_merchant_id_COUNT                        int64
# hcard_id_merchant_id_NUNIQUE                      int64
# hcard_id_df_season_purchase_date_MIN              uint8
# hcard_id_df_season_purchase_date_MAX              uint8
# hcard_id_df_season_purchase_date_VAR            float64
# hcard_id_df_season_purchase_date_MEAN           float64
# hcard_id_df_season_purchase_date_STD            float64
# hcard_id_df_season_purchase_date_COUNT            int64
# hcard_id_df_season_purchase_date_NUNIQUE          int64
# hcard_id_df_hour_purchase_date_MIN                uint8
# hcard_id_df_hour_purchase_date_MAX                uint8
# hcard_id_df_hour_purchase_date_VAR              float64
# hcard_id_df_hour_purchase_date_MEAN             float64
# hcard_id_df_hour_purchase_date_STD              float64
# hcard_id_df_hour_purchase_date_COUNT              int64
# hcard_id_df_hour_purchase_date_NUNIQUE            int64
# hcard_id_df_year_purchase_date_MIN               uint16
# hcard_id_df_year_purchase_date_MAX               uint16
# hcard_id_df_year_purchase_date_VAR              float64
# hcard_id_df_year_purchase_date_MEAN             float64
# hcard_id_df_year_purchase_date_STD              float64
# hcard_id_df_year_purchase_date_COUNT              int64
# hcard_id_df_year_purchase_date_NUNIQUE            int64
# hcard_id_df_quarter_purchase_date_MIN             uint8
# hcard_id_df_quarter_purchase_date_MAX             uint8
# hcard_id_df_quarter_purchase_date_VAR           float64
# hcard_id_df_quarter_purchase_date_MEAN          float64
# hcard_id_df_quarter_purchase_date_STD           float64
# hcard_id_df_quarter_purchase_date_COUNT           int64
# hcard_id_df_quarter_purchase_date_NUNIQUE         int64
# hcard_id_df_yearmonth_purchase_date_MIN          uint16
# hcard_id_df_yearmonth_purchase_date_MAX          uint16
# hcard_id_df_yearmonth_purchase_date_VAR         float64
# hcard_id_df_yearmonth_purchase_date_MEAN        float64
# hcard_id_df_yearmonth_purchase_date_STD         float64
# hcard_id_df_yearmonth_purchase_date_COUNT         int64
# hcard_id_df_yearmonth_purchase_date_NUNIQUE       int64
# hcard_id_df_month_purchase_date_MIN               uint8
# hcard_id_df_month_purchase_date_MAX               uint8
# hcard_id_df_month_purchase_date_VAR             float64
# hcard_id_df_month_purchase_date_MEAN            float64
# hcard_id_df_month_purchase_date_STD             float64
# hcard_id_df_month_purchase_date_COUNT             int64
# hcard_id_df_month_purchase_date_NUNIQUE           int64
# hcard_id_df_day_purchase_date_MIN                 uint8
# hcard_id_df_day_purchase_date_MAX                 uint8
# hcard_id_df_day_purchase_date_VAR               float64
# hcard_id_df_day_purchase_date_MEAN              float64
# hcard_id_df_day_purchase_date_STD               float64
# hcard_id_df_day_purchase_date_COUNT               int64
# hcard_id_df_day_purchase_date_NUNIQUE             int64
# hcard_id_df_weekday_purchase_date_MIN             uint8
# hcard_id_df_weekday_purchase_date_MAX             uint8
# hcard_id_df_weekday_purchase_date_VAR           float64
# hcard_id_df_weekday_purchase_date_MEAN          float64
# hcard_id_df_weekday_purchase_date_STD           float64
# hcard_id_df_weekday_purchase_date_COUNT           int64
# hcard_id_df_weekday_purchase_date_NUNIQUE         int64
# hcard_id_merchant_group_id_COUNT                  int64
# hcard_id_merchant_group_id_NUNIQUE                int64
# hcard_id_numerical_1_MEAN                       float64
# hcard_id_numerical_2_MEAN                       float64
# hcard_id_category_1_mcts_COUNT                    int64
# hcard_id_category_1_mcts_NUNIQUE                  int64
# hcard_id_category_1_mcts_SUM                      int64
# hcard_id_category_1_mcts_MEAN                   float64
# hcard_id_avg_sales_lag3_MEAN                    float64
# hcard_id_avg_purchases_lag3_MEAN                float64
# hcard_id_active_months_lag3_MEAN                float64
# hcard_id_avg_sales_lag6_MEAN                    float64
# hcard_id_avg_purchases_lag6_MEAN                float64
# hcard_id_active_months_lag6_MEAN                float64
# hcard_id_avg_sales_lag12_MEAN                   float64
# hcard_id_avg_purchases_lag12_MEAN               float64
# hcard_id_active_months_lag12_MEAN               float64
# hcard_id_df_weekofyear_purchase_date_MIN          int64
# hcard_id_df_weekofyear_purchase_date_MAX          int64
# hcard_id_df_weekofyear_purchase_date_VAR        float64
# hcard_id_df_weekofyear_purchase_date_MEAN       float64
# hcard_id_df_weekofyear_purchase_date_STD        float64
# hcard_id_df_weekofyear_purchase_date_COUNT        int64
# hcard_id_df_weekofyear_purchase_date_NUNIQUE      int64
# hcard_id_df_weekend_purchase_date_MIN             int64
# hcard_id_df_weekend_purchase_date_MAX             int64
# hcard_id_df_weekend_purchase_date_VAR           float64
# hcard_id_df_weekend_purchase_date_MEAN          float64
# hcard_id_df_weekend_purchase_date_STD           float64
# hcard_id_df_weekend_purchase_date_COUNT           int64
# hcard_id_df_weekend_purchase_date_NUNIQUE         int64
# dtype: object

# %%
train['hist_purchase_date_max'] = pd.to_datetime(train['hcard_id_purchase_date_MAX'])
train['hist_purchase_date_min'] = pd.to_datetime(train['hcard_id_purchase_date_MIN'])
train['hist_purchase_date_diff'] = (train['hist_purchase_date_max'] - train['hist_purchase_date_min']).dt.days
#train['hist_purchase_date_average'] = train['hist_purchase_date_diff']/train['hist_card_id_size']
train['hist_purchase_date_uptonow'] = (datetime.today() - train['hist_purchase_date_max']).dt.days
train['hist_first_buy'] = (train['hist_purchase_date_min'] - pd.to_datetime(train['first_active_month'])).dt.days
for feature in ['hist_purchase_date_max','hist_purchase_date_min']:
    train[feature] = train[feature].astype(np.int64) * 1e-9

# %%
test['hist_purchase_date_max'] = pd.to_datetime(test['hcard_id_purchase_date_MAX'])
test['hist_purchase_date_min'] = pd.to_datetime(test['hcard_id_purchase_date_MIN'])
test['hist_purchase_date_diff'] = (test['hist_purchase_date_max'] - test['hist_purchase_date_min']).dt.days
#test['hist_purchase_date_average'] = test['hist_purchase_date_diff']/test['hist_card_id_size']
test['hist_purchase_date_uptonow'] = (datetime.today() - test['hist_purchase_date_max']).dt.days
test['hist_first_buy'] = (test['hist_purchase_date_min'] - pd.to_datetime(test['first_active_month'])).dt.days
for feature in ['hist_purchase_date_max','hist_purchase_date_min']:
    test[feature] = test[feature].astype(np.int64) * 1e-9

# %%
train['new_purchase_date_max'] = pd.to_datetime(train['card_id_purchase_date_MAX'])
train['new_purchase_date_min'] = pd.to_datetime(train['card_id_purchase_date_MIN'])
train['new_purchase_date_diff'] = (train['new_purchase_date_max'] - train['new_purchase_date_min']).dt.days
#train['new_purchase_date_average'] = train['new_purchase_date_diff']/train['new_card_id_size']
train['new_purchase_date_uptonow'] = (datetime.today() - train['new_purchase_date_max']).dt.days
train['new_first_buy'] = (train['new_purchase_date_min'] - pd.to_datetime(train['first_active_month'])).dt.days
for feature in ['new_purchase_date_max','new_purchase_date_min']:
    train[feature] = train[feature].astype(np.int64) * 1e-9

test['new_purchase_date_max'] = pd.to_datetime(test['hcard_id_purchase_date_MAX'])
test['new_purchase_date_min'] = pd.to_datetime(test['hcard_id_purchase_date_MIN'])
test['new_purchase_date_diff'] = (test['new_purchase_date_max'] - test['new_purchase_date_min']).dt.days
#test['new_purchase_date_average'] = test['new_purchase_date_diff']/test['new_card_id_size']
test['new_purchase_date_uptonow'] = (datetime.today() - test['new_purchase_date_max']).dt.days
test['new_first_buy'] = (test['new_purchase_date_min'] - pd.to_datetime(test['first_active_month'])).dt.days
for feature in ['new_purchase_date_max','new_purchase_date_min']:
    test[feature] = test[feature].astype(np.int64) * 1e-9

# %%
train.dtypes
# Out:
# first_active_month                               object
# card_id                                          object
# feature_1                                         int64
# feature_2                                         int64
# feature_3                                         int64
# target                                          float64
# active_since_months                               int64
# card_id_authorized_flag_SUM                     float64
# card_id_authorized_flag_MEAN                    float64
# card_id_city_id_COUNT                           float64
# card_id_city_id_NUNIQUE                         float64
# card_id_purchase_date_PTP                       float64
# card_id_purchase_date_MIN                       float64
# card_id_purchase_date_MAX                       float64
# card_id_purchase_amount_MIN                     float64
# card_id_purchase_amount_MAX                     float64
# card_id_purchase_amount_VAR                     float64
# card_id_purchase_amount_SUM                     float64
# card_id_purchase_amount_MEAN                    float64
# card_id_purchase_amount_STD                     float64
# card_id_installments_MIN                        float64
# card_id_installments_MAX                        float64
# card_id_installments_VAR                        float64
# card_id_installments_SUM                        float64
# card_id_installments_MEAN                       float64
# card_id_installments_STD                        float64
# card_id_month_lag_MIN                           float64
# card_id_month_lag_MAX                           float64
# card_id_month_lag_VAR                           float64
# card_id_month_lag_SUM                           float64
# card_id_month_lag_MEAN                          float64
# card_id_month_lag_STD                           float64
# card_id_state_id_COUNT                          float64
# card_id_state_id_NUNIQUE                        float64
# card_id_subsector_id_COUNT                      float64
# card_id_subsector_id_NUNIQUE                    float64
# card_id_merchant_category_id_COUNT              float64
# card_id_merchant_category_id_NUNIQUE            float64
# card_id_category_1_COUNT                        float64
# card_id_category_1_NUNIQUE                      float64
# card_id_category_1_SUM                          float64
# card_id_category_1_MEAN                         float64
# card_id_category_2_COUNT                        float64
# card_id_category_2_NUNIQUE                      float64
# card_id_category_3_COUNT                        float64
# card_id_category_3_NUNIQUE                      float64
# card_id_merchant_id_COUNT                       float64
# card_id_merchant_id_NUNIQUE                     float64
# card_id_df_season_purchase_date_MIN             float64
# card_id_df_season_purchase_date_MAX             float64
# card_id_df_season_purchase_date_VAR             float64
# card_id_df_season_purchase_date_MEAN            float64
# card_id_df_season_purchase_date_STD             float64
# card_id_df_season_purchase_date_COUNT           float64
# card_id_df_season_purchase_date_NUNIQUE         float64
# card_id_df_hour_purchase_date_MIN               float64
# card_id_df_hour_purchase_date_MAX               float64
# card_id_df_hour_purchase_date_VAR               float64
# card_id_df_hour_purchase_date_MEAN              float64
# card_id_df_hour_purchase_date_STD               float64
# card_id_df_hour_purchase_date_COUNT             float64
# card_id_df_hour_purchase_date_NUNIQUE           float64
# card_id_df_year_purchase_date_MIN               float64
# card_id_df_year_purchase_date_MAX               float64
# card_id_df_year_purchase_date_VAR               float64
# card_id_df_year_purchase_date_MEAN              float64
# card_id_df_year_purchase_date_STD               float64
# card_id_df_year_purchase_date_COUNT             float64
# card_id_df_year_purchase_date_NUNIQUE           float64
# card_id_df_quarter_purchase_date_MIN            float64
# card_id_df_quarter_purchase_date_MAX            float64
# card_id_df_quarter_purchase_date_VAR            float64
# card_id_df_quarter_purchase_date_MEAN           float64
# card_id_df_quarter_purchase_date_STD            float64
# card_id_df_quarter_purchase_date_COUNT          float64
# card_id_df_quarter_purchase_date_NUNIQUE        float64
# card_id_df_yearmonth_purchase_date_MIN          float64
# card_id_df_yearmonth_purchase_date_MAX          float64
# card_id_df_yearmonth_purchase_date_VAR          float64
# card_id_df_yearmonth_purchase_date_MEAN         float64
# card_id_df_yearmonth_purchase_date_STD          float64
# card_id_df_yearmonth_purchase_date_COUNT        float64
# card_id_df_yearmonth_purchase_date_NUNIQUE      float64
# card_id_df_month_purchase_date_MIN              float64
# card_id_df_month_purchase_date_MAX              float64
# card_id_df_month_purchase_date_VAR              float64
# card_id_df_month_purchase_date_MEAN             float64
# card_id_df_month_purchase_date_STD              float64
# card_id_df_month_purchase_date_COUNT            float64
# card_id_df_month_purchase_date_NUNIQUE          float64
# card_id_df_day_purchase_date_MIN                float64
# card_id_df_day_purchase_date_MAX                float64
# card_id_df_day_purchase_date_VAR                float64
# card_id_df_day_purchase_date_MEAN               float64
# card_id_df_day_purchase_date_STD                float64
# card_id_df_day_purchase_date_COUNT              float64
# card_id_df_day_purchase_date_NUNIQUE            float64
# card_id_df_weekday_purchase_date_MIN            float64
# card_id_df_weekday_purchase_date_MAX            float64
# card_id_df_weekday_purchase_date_VAR            float64
# card_id_df_weekday_purchase_date_MEAN           float64
# card_id_df_weekday_purchase_date_STD            float64
# card_id_df_weekday_purchase_date_COUNT          float64
# card_id_df_weekday_purchase_date_NUNIQUE        float64
# card_id_merchant_group_id_COUNT                 float64
# card_id_merchant_group_id_NUNIQUE               float64
# card_id_numerical_1_MEAN                        float64
# card_id_numerical_2_MEAN                        float64
# card_id_category_1_mcts_COUNT                   float64
# card_id_category_1_mcts_NUNIQUE                 float64
# card_id_category_1_mcts_SUM                     float64
# card_id_category_1_mcts_MEAN                    float64
# card_id_avg_sales_lag3_MEAN                     float64
# card_id_avg_purchases_lag3_MEAN                 float64
# card_id_active_months_lag3_MEAN                 float64
# card_id_avg_sales_lag6_MEAN                     float64
# card_id_avg_purchases_lag6_MEAN                 float64
# card_id_active_months_lag6_MEAN                 float64
# card_id_avg_sales_lag12_MEAN                    float64
# card_id_avg_purchases_lag12_MEAN                float64
# card_id_active_months_lag12_MEAN                float64
# card_id_df_weekofyear_purchase_date_MIN         float64
# card_id_df_weekofyear_purchase_date_MAX         float64
# card_id_df_weekofyear_purchase_date_VAR         float64
# card_id_df_weekofyear_purchase_date_MEAN        float64
# card_id_df_weekofyear_purchase_date_STD         float64
# card_id_df_weekofyear_purchase_date_COUNT       float64
# card_id_df_weekofyear_purchase_date_NUNIQUE     float64
# card_id_df_weekend_purchase_date_MIN            float64
# card_id_df_weekend_purchase_date_MAX            float64
# card_id_df_weekend_purchase_date_VAR            float64
# card_id_df_weekend_purchase_date_MEAN           float64
# card_id_df_weekend_purchase_date_STD            float64
# card_id_df_weekend_purchase_date_COUNT          float64
# card_id_df_weekend_purchase_date_NUNIQUE        float64
# hcard_id_authorized_flag_SUM                      int64
# hcard_id_authorized_flag_MEAN                   float64
# hcard_id_city_id_COUNT                            int64
# hcard_id_city_id_NUNIQUE                          int64
# hcard_id_purchase_date_PTP                      float64
# hcard_id_purchase_date_MIN                      float64
# hcard_id_purchase_date_MAX                      float64
# hcard_id_purchase_amount_MIN                    float64
# hcard_id_purchase_amount_MAX                    float64
# hcard_id_purchase_amount_VAR                    float64
# hcard_id_purchase_amount_SUM                    float64
# hcard_id_purchase_amount_MEAN                   float64
# hcard_id_purchase_amount_STD                    float64
# hcard_id_installments_MIN                         int16
# hcard_id_installments_MAX                         int16
# hcard_id_installments_VAR                       float64
# hcard_id_installments_SUM                         int16
# hcard_id_installments_MEAN                      float64
# hcard_id_installments_STD                       float64
# hcard_id_month_lag_MIN                            uint8
# hcard_id_month_lag_MAX                            uint8
# hcard_id_month_lag_VAR                          float64
# hcard_id_month_lag_SUM                          float64
# hcard_id_month_lag_MEAN                         float64
# hcard_id_month_lag_STD                          float64
# hcard_id_state_id_COUNT                           int64
# hcard_id_state_id_NUNIQUE                         int64
# hcard_id_subsector_id_COUNT                       int64
# hcard_id_subsector_id_NUNIQUE                     int64
# hcard_id_merchant_category_id_COUNT               int64
# hcard_id_merchant_category_id_NUNIQUE             int64
# hcard_id_category_1_COUNT                         int64
# hcard_id_category_1_NUNIQUE                       int64
# hcard_id_category_1_SUM                           int64
# hcard_id_category_1_MEAN                        float64
# hcard_id_category_2_COUNT                         int64
# hcard_id_category_2_NUNIQUE                       int64
# hcard_id_category_3_COUNT                         int64
# hcard_id_category_3_NUNIQUE                       int64
# hcard_id_merchant_id_COUNT                        int64
# hcard_id_merchant_id_NUNIQUE                      int64
# hcard_id_df_season_purchase_date_MIN              uint8
# hcard_id_df_season_purchase_date_MAX              uint8
# hcard_id_df_season_purchase_date_VAR            float64
# hcard_id_df_season_purchase_date_MEAN           float64
# hcard_id_df_season_purchase_date_STD            float64
# hcard_id_df_season_purchase_date_COUNT            int64
# hcard_id_df_season_purchase_date_NUNIQUE          int64
# hcard_id_df_hour_purchase_date_MIN                uint8
# hcard_id_df_hour_purchase_date_MAX                uint8
# hcard_id_df_hour_purchase_date_VAR              float64
# hcard_id_df_hour_purchase_date_MEAN             float64
# hcard_id_df_hour_purchase_date_STD              float64
# hcard_id_df_hour_purchase_date_COUNT              int64
# hcard_id_df_hour_purchase_date_NUNIQUE            int64
# hcard_id_df_year_purchase_date_MIN               uint16
# hcard_id_df_year_purchase_date_MAX               uint16
# hcard_id_df_year_purchase_date_VAR              float64
# hcard_id_df_year_purchase_date_MEAN             float64
# hcard_id_df_year_purchase_date_STD              float64
# hcard_id_df_year_purchase_date_COUNT              int64
# hcard_id_df_year_purchase_date_NUNIQUE            int64
# hcard_id_df_quarter_purchase_date_MIN             uint8
# hcard_id_df_quarter_purchase_date_MAX             uint8
# hcard_id_df_quarter_purchase_date_VAR           float64
# hcard_id_df_quarter_purchase_date_MEAN          float64
# hcard_id_df_quarter_purchase_date_STD           float64
# hcard_id_df_quarter_purchase_date_COUNT           int64
# hcard_id_df_quarter_purchase_date_NUNIQUE         int64
# hcard_id_df_yearmonth_purchase_date_MIN          uint16
# hcard_id_df_yearmonth_purchase_date_MAX          uint16
# hcard_id_df_yearmonth_purchase_date_VAR         float64
# hcard_id_df_yearmonth_purchase_date_MEAN        float64
# hcard_id_df_yearmonth_purchase_date_STD         float64
# hcard_id_df_yearmonth_purchase_date_COUNT         int64
# hcard_id_df_yearmonth_purchase_date_NUNIQUE       int64
# hcard_id_df_month_purchase_date_MIN               uint8
# hcard_id_df_month_purchase_date_MAX               uint8
# hcard_id_df_month_purchase_date_VAR             float64
# hcard_id_df_month_purchase_date_MEAN            float64
# hcard_id_df_month_purchase_date_STD             float64
# hcard_id_df_month_purchase_date_COUNT             int64
# hcard_id_df_month_purchase_date_NUNIQUE           int64
# hcard_id_df_day_purchase_date_MIN                 uint8
# hcard_id_df_day_purchase_date_MAX                 uint8
# hcard_id_df_day_purchase_date_VAR               float64
# hcard_id_df_day_purchase_date_MEAN              float64
# hcard_id_df_day_purchase_date_STD               float64
# hcard_id_df_day_purchase_date_COUNT               int64
# hcard_id_df_day_purchase_date_NUNIQUE             int64
# hcard_id_df_weekday_purchase_date_MIN             uint8
# hcard_id_df_weekday_purchase_date_MAX             uint8
# hcard_id_df_weekday_purchase_date_VAR           float64
# hcard_id_df_weekday_purchase_date_MEAN          float64
# hcard_id_df_weekday_purchase_date_STD           float64
# hcard_id_df_weekday_purchase_date_COUNT           int64
# hcard_id_df_weekday_purchase_date_NUNIQUE         int64
# hcard_id_merchant_group_id_COUNT                  int64
# hcard_id_merchant_group_id_NUNIQUE                int64
# hcard_id_numerical_1_MEAN                       float64
# hcard_id_numerical_2_MEAN                       float64
# hcard_id_category_1_mcts_COUNT                    int64
# hcard_id_category_1_mcts_NUNIQUE                  int64
# hcard_id_category_1_mcts_SUM                      int64
# hcard_id_category_1_mcts_MEAN                   float64
# hcard_id_avg_sales_lag3_MEAN                    float64
# hcard_id_avg_purchases_lag3_MEAN                float64
# hcard_id_active_months_lag3_MEAN                float64
# hcard_id_avg_sales_lag6_MEAN                    float64
# hcard_id_avg_purchases_lag6_MEAN                float64
# hcard_id_active_months_lag6_MEAN                float64
# hcard_id_avg_sales_lag12_MEAN                   float64
# hcard_id_avg_purchases_lag12_MEAN               float64
# hcard_id_active_months_lag12_MEAN               float64
# hcard_id_df_weekofyear_purchase_date_MIN          int64
# hcard_id_df_weekofyear_purchase_date_MAX          int64
# hcard_id_df_weekofyear_purchase_date_VAR        float64
# hcard_id_df_weekofyear_purchase_date_MEAN       float64
# hcard_id_df_weekofyear_purchase_date_STD        float64
# hcard_id_df_weekofyear_purchase_date_COUNT        int64
# hcard_id_df_weekofyear_purchase_date_NUNIQUE      int64
# hcard_id_df_weekend_purchase_date_MIN             int64
# hcard_id_df_weekend_purchase_date_MAX             int64
# hcard_id_df_weekend_purchase_date_VAR           float64
# hcard_id_df_weekend_purchase_date_MEAN          float64
# hcard_id_df_weekend_purchase_date_STD           float64
# hcard_id_df_weekend_purchase_date_COUNT           int64
# hcard_id_df_weekend_purchase_date_NUNIQUE         int64
# hist_purchase_date_max                          float64
# hist_purchase_date_min                          float64
# hist_purchase_date_diff                           int64
# hist_purchase_date_uptonow                        int64
# hist_first_buy                                    int64
# new_purchase_date_max                           float64
# new_purchase_date_min                           float64
# new_purchase_date_diff                          float64
# new_purchase_date_uptonow                       float64
# new_first_buy                                   float64
# dtype: object

# %% [raw]
# train['outliers'] = 0
# train.loc[train['target'] < -30, 'outliers'] = 1

# %% [raw]
# train.head()

# %% [raw]
# X = train.drop(['first_active_month','card_id','target','df_temp_purchase_date'],axis=1,errors='ignore')
# y = train['target']
# X_test = test.drop(['first_active_month','card_id'],axis=1,errors='ignore')

# %% [raw]
# X = train.drop(['first_active_month','card_id','target','df_temp_purchase_date','card_id_subsector_id_dummy_40_SUM'
#                'card_id_subsector_id_dummy_24_SUM'],axis=1,errors='ignore')
# y = train['target']
# X_test = test.drop(['first_active_month','card_id'],axis=1,errors='ignore')

# %% [raw]
# train.dtypes

# %% [raw]
# X_test.to_csv(root + '/X_test.csv', index=False)
# X.to_csv(root + '/X.csv', index=False)
# y.to_csv(root + '/y.csv', index=False)

# %% [raw]
# cardcols = [x for x in X.columns.tolist() if x.startswith('card_id') ]
# for colname in cardcols:
#     X[colname  + '_DIFF'] = X[colname] -  X['h' + colname]
#     X_test[colname  + '_DIFF'] = X_test[colname] -  X_test['h' + colname]
#     X[colname  + '_AVG'] = (X[colname] +  X['h' + colname])/2
#     X_test[colname  + '_AVG'] = (X_test[colname] +  X_test['h' + colname])/2

# %% [raw]
# X.dtypes

# %%
# %%time

import lightgbm as lgb

lgb_params = {"objective" : "regression", "metric" : "rmse", 
               "max_depth": 9, "min_child_samples": 20, 
              "reg_alpha": 1, "reg_lambda": 1,
              "num_leaves" : 64, "learning_rate" : 0.005, 
               "subsample" : 0.8, "colsample_bytree" : 0.8, "num_threads" : 16,"random_seed" : 47,
               "verbosity": -1}

features_to_drop = ['first_active_month','card_id','target','df_temp_purchase_date'
                    ,'hcard_id_purchase_date_MIN','hcard_id_purchase_date_MAX'
                    ,'card_id_purchase_date_MIN','card_id_purchase_date_MAX'
                   # ,'card_id_category_1_COUNT','card_id_category_1_MEAN','hcard_id_subsector_id_dummy_20_SUM'
                   #,'card_id_subsector_id_dummy_40_SUM','card_id_subsector_id_dummy_24_SUM' 
                   ] #

featuresToAdd = [
'hcard_id_most_recent_sales_range_dummy_A_SUM',
'hcard_id_most_recent_sales_range_dummy_B_SUM',
'hcard_id_most_recent_sales_range_dummy_C_SUM',
'hcard_id_most_recent_sales_range_dummy_D_SUM',
'hcard_id_most_recent_sales_range_dummy_E_SUM',
'hcard_id_most_recent_purchases_range_dummy_A_SUM',
'hcard_id_most_recent_purchases_range_dummy_B_SUM',
'hcard_id_most_recent_purchases_range_dummy_C_SUM',
'hcard_id_most_recent_purchases_range_dummy_D_SUM',
'hcard_id_most_recent_purchases_range_dummy_E_SUM',
'hcard_id_category_4_dummy_N_SUM',
'hcard_id_category_4_dummy_Y_SUM',
'hcard_id_merchant_group_id_COUNT',
'hcard_id_merchant_group_id_NUNIQUE',
'hcard_id_numerical_1_MEAN',
'hcard_id_numerical_2_MEAN',
'hcard_id_category_1_mcts_COUNT',
'hcard_id_category_1_mcts_NUNIQUE',
'hcard_id_category_1_mcts_SUM',
'hcard_id_category_1_mcts_MEAN',
'hcard_id_avg_sales_lag3_MEAN',
'hcard_id_avg_purchases_lag3_MEAN',
'hcard_id_active_months_lag3_MEAN',
'hcard_id_avg_sales_lag6_MEAN',
'hcard_id_avg_purchases_lag6_MEAN',
'hcard_id_active_months_lag6_MEAN',
'hcard_id_avg_sales_lag12_MEAN',
'hcard_id_avg_purchases_lag12_MEAN',
'hcard_id_active_months_lag12_MEAN',
'card_id_most_recent_sales_range_dummy_A_SUM',
'card_id_most_recent_sales_range_dummy_B_SUM',
'card_id_most_recent_sales_range_dummy_C_SUM',
'card_id_most_recent_sales_range_dummy_D_SUM',
'card_id_most_recent_sales_range_dummy_E_SUM',
'card_id_most_recent_purchases_range_dummy_A_SUM',
'card_id_most_recent_purchases_range_dummy_B_SUM',
'card_id_most_recent_purchases_range_dummy_C_SUM',
'card_id_most_recent_purchases_range_dummy_D_SUM',
'card_id_most_recent_purchases_range_dummy_E_SUM',
'card_id_category_4_dummy_N_SUM',
'card_id_category_4_dummy_Y_SUM',
'card_id_merchant_group_id_COUNT',
'card_id_merchant_group_id_NUNIQUE',
'card_id_numerical_1_MEAN',
'card_id_numerical_2_MEAN',
'card_id_category_1_mcts_COUNT',
'card_id_category_1_mcts_NUNIQUE',
'card_id_category_1_mcts_SUM',
'card_id_category_1_mcts_MEAN',
'card_id_avg_sales_lag3_MEAN',
'card_id_avg_purchases_lag3_MEAN',
'card_id_active_months_lag3_MEAN',
'card_id_avg_sales_lag6_MEAN',
'card_id_avg_purchases_lag6_MEAN',
'card_id_active_months_lag6_MEAN',
'card_id_avg_sales_lag12_MEAN',
'card_id_avg_purchases_lag12_MEAN',
'card_id_active_months_lag12_MEAN',
'card_id_df_weekofyear_purchase_date_MIN',         
'card_id_df_weekofyear_purchase_date_MAX',         
'card_id_df_weekofyear_purchase_date_VAR',         
'card_id_df_weekofyear_purchase_date_MEAN',        
'card_id_df_weekofyear_purchase_date_STD',         
'card_id_df_weekofyear_purchase_date_COUNT',       
'card_id_df_weekofyear_purchase_date_NUNIQUE',     
'card_id_df_weekend_purchase_date_MIN',            
'card_id_df_weekend_purchase_date_MAX',            
'card_id_df_weekend_purchase_date_VAR',            
'card_id_df_weekend_purchase_date_MEAN',           
'card_id_df_weekend_purchase_date_STD',            
'card_id_df_weekend_purchase_date_COUNT',          
'card_id_df_weekend_purchase_date_NUNIQUE',        
'hcard_id_df_weekofyear_purchase_date_MIN',          
'hcard_id_df_weekofyear_purchase_date_MAX',          
'hcard_id_df_weekofyear_purchase_date_VAR',        
'hcard_id_df_weekofyear_purchase_date_MEAN',       
'hcard_id_df_weekofyear_purchase_date_STD',        
'hcard_id_df_weekofyear_purchase_date_COUNT',        
'hcard_id_df_weekofyear_purchase_date_NUNIQUE',      
'hcard_id_df_weekend_purchase_date_MIN',             
'hcard_id_df_weekend_purchase_date_MAX',             
'hcard_id_df_weekend_purchase_date_VAR',           
'hcard_id_df_weekend_purchase_date_MEAN',          
'hcard_id_df_weekend_purchase_date_STD',           
'hcard_id_df_weekend_purchase_date_COUNT',           
'hcard_id_df_weekend_purchase_date_NUNIQUE',
]


X = train.drop(features_to_drop,axis=1,errors='ignore') 
y = train['target']
X_test = test.drop(features_to_drop,axis=1,errors='ignore')

FOLDs = KFold(n_splits=15, shuffle=True, random_state=100)

oof_lgb = np.zeros(len(X))
predictions_lgb = np.zeros(len(X_test))

features_lgb = list(X.columns)
feature_importance_df_lgb = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(FOLDs.split(X)):
    trn_data = lgb.Dataset(X.iloc[trn_idx], label=y.iloc[trn_idx])
    val_data = lgb.Dataset(X.iloc[val_idx], label=y.iloc[val_idx])

    print("LGB " + str(fold_) + "-" * 100)
    num_round = 10000
    clf = lgb.train(lgb_params, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, 
                    early_stopping_rounds = 100)
    oof_lgb[val_idx] = clf.predict(X.iloc[val_idx], num_iteration=clf.best_iteration)

    fold_importance_df_lgb = pd.DataFrame()
    fold_importance_df_lgb["feature"] = features_lgb
    fold_importance_df_lgb["importance"] = clf.feature_importance()
    fold_importance_df_lgb["fold"] = fold_ + 1
    feature_importance_df_lgb = pd.concat([feature_importance_df_lgb, fold_importance_df_lgb], axis=0)
    predictions_lgb += clf.predict(X_test, num_iteration=clf.best_iteration) / FOLDs.n_splits
    currentScore = np.sqrt(mean_squared_error(oof_lgb, y))


    print(currentScore)
# Out:
# LGB 0----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.39154	valid_1's rmse: 3.31812
# Early stopping, best iteration is:
# [1029]	training's rmse: 3.38619	valid_1's rmse: 3.3178
# 3.8589852872069748
# LGB 1----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.37574	valid_1's rmse: 3.53638
# Early stopping, best iteration is:
# [1133]	training's rmse: 3.35209	valid_1's rmse: 3.53589
# 3.8476242218050385
# LGB 2----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.36584	valid_1's rmse: 3.68265
# Early stopping, best iteration is:
# [1163]	training's rmse: 3.33792	valid_1's rmse: 3.68203
# 3.83626737017441
# LGB 3----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.36394	valid_1's rmse: 3.70886
# Early stopping, best iteration is:
# [1315]	training's rmse: 3.31189	valid_1's rmse: 3.70633
# 3.8206776389930335
# LGB 4----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.37179	valid_1's rmse: 3.61813
# Early stopping, best iteration is:
# [1243]	training's rmse: 3.33048	valid_1's rmse: 3.61593
# 3.806875453938417
# LGB 5----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.37761	valid_1's rmse: 3.54101
# Early stopping, best iteration is:
# [1844]	training's rmse: 3.25395	valid_1's rmse: 3.537
# 3.7932635181934096
# LGB 6----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.37508	valid_1's rmse: 3.63247
# [2000]	training's rmse: 3.23678	valid_1's rmse: 3.62399
# Early stopping, best iteration is:
# [1964]	training's rmse: 3.24113	valid_1's rmse: 3.6237
# 3.776690221267116
# LGB 7----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.3625	valid_1's rmse: 3.751
# [2000]	training's rmse: 3.22091	valid_1's rmse: 3.74426
# Early stopping, best iteration is:
# [1943]	training's rmse: 3.22783	valid_1's rmse: 3.74392
# 3.7633768355207557
# LGB 8----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.36476	valid_1's rmse: 3.76605
# Early stopping, best iteration is:
# [1734]	training's rmse: 3.25352	valid_1's rmse: 3.76139
# 3.74630766941092
# LGB 9----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.36838	valid_1's rmse: 3.68833
# Early stopping, best iteration is:
# [1180]	training's rmse: 3.33678	valid_1's rmse: 3.68765
# 3.7313923930279813
# LGB 10----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.38019	valid_1's rmse: 3.52485
# Early stopping, best iteration is:
# [1327]	training's rmse: 3.32757	valid_1's rmse: 3.52301
# 3.716342483478828
# LGB 11----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.35998	valid_1's rmse: 3.75221
# Early stopping, best iteration is:
# [1694]	training's rmse: 3.25528	valid_1's rmse: 3.74881
# 3.703999182793302
# LGB 12----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.3557	valid_1's rmse: 3.88569
# [2000]	training's rmse: 3.21535	valid_1's rmse: 3.87714
# Early stopping, best iteration is:
# [1978]	training's rmse: 3.21755	valid_1's rmse: 3.87698
# 3.6842297655318115
# LGB 13----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.37415	valid_1's rmse: 3.59553
# Early stopping, best iteration is:
# [1390]	training's rmse: 3.30954	valid_1's rmse: 3.5922
# 3.668961576557333
# LGB 14----------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's rmse: 3.35995	valid_1's rmse: 3.80228
# Early stopping, best iteration is:
# [1425]	training's rmse: 3.29322	valid_1's rmse: 3.79989
# 3.652613692190228
# Wall time: 20min 45s

# %% [raw]
# X.dtypes

# %%
# %%time

import lightgbm as lgb

lgb_params = {"objective" : "regression", "metric" : "rmse", 
               "max_depth": 9, "min_child_samples": 20, 
              "reg_alpha": 1, "reg_lambda": 1,
              "num_leaves" : 64, "learning_rate" : 0.1, 
               "subsample" : 0.8, "colsample_bytree" : 0.8, "num_threads" : 16,"random_seed" : 47,
               "verbosity": -1}

lowfeatures = [''] 
'''+ [
'hcard_id_most_recent_sales_range_dummy_B_SUM',
'hcard_id_most_recent_sales_range_dummy_C_SUM',
'hcard_id_most_recent_sales_range_dummy_D_SUM',
'hcard_id_most_recent_sales_range_dummy_E_SUM',
'hcard_id_most_recent_purchases_range_dummy_A_SUM',
'hcard_id_most_recent_purchases_range_dummy_B_SUM',
'hcard_id_most_recent_purchases_range_dummy_C_SUM',
'hcard_id_most_recent_purchases_range_dummy_D_SUM',
'hcard_id_most_recent_purchases_range_dummy_E_SUM',
'hcard_id_category_4_dummy_N_SUM',
'hcard_id_category_4_dummy_Y_SUM',
'hcard_id_merchant_group_id_COUNT',
'hcard_id_merchant_group_id_NUNIQUE',
'hcard_id_numerical_1_MEAN',
'hcard_id_numerical_2_MEAN',
'hcard_id_category_1_mcts_COUNT',
'hcard_id_category_1_mcts_NUNIQUE',
'hcard_id_category_1_mcts_SUM',
'hcard_id_category_1_mcts_MEAN',
'hcard_id_avg_sales_lag3_MEAN',
'hcard_id_avg_purchases_lag3_MEAN',
'hcard_id_active_months_lag3_MEAN',
'hcard_id_avg_sales_lag6_MEAN',
'hcard_id_avg_purchases_lag6_MEAN',
'hcard_id_active_months_lag6_MEAN',
'hcard_id_avg_sales_lag12_MEAN',
'hcard_id_avg_purchases_lag12_MEAN',
'hcard_id_active_months_lag12_MEAN',
'card_id_most_recent_sales_range_dummy_A_SUM',
'card_id_most_recent_sales_range_dummy_B_SUM',
'card_id_most_recent_sales_range_dummy_C_SUM',
'card_id_most_recent_sales_range_dummy_D_SUM',
'card_id_most_recent_sales_range_dummy_E_SUM',
'card_id_most_recent_purchases_range_dummy_A_SUM',
'card_id_most_recent_purchases_range_dummy_B_SUM',
'card_id_most_recent_purchases_range_dummy_C_SUM',
'card_id_most_recent_purchases_range_dummy_D_SUM',
'card_id_most_recent_purchases_range_dummy_E_SUM',
'card_id_category_4_dummy_N_SUM',
'card_id_category_4_dummy_Y_SUM',
'card_id_merchant_group_id_COUNT',
'card_id_merchant_group_id_NUNIQUE',
'card_id_numerical_1_MEAN',
'card_id_numerical_2_MEAN',
'card_id_category_1_mcts_COUNT',
'card_id_category_1_mcts_NUNIQUE',
'card_id_category_1_mcts_SUM',
'card_id_category_1_mcts_MEAN',
'card_id_avg_sales_lag3_MEAN',
'card_id_avg_purchases_lag3_MEAN',
'card_id_active_months_lag3_MEAN',
'card_id_avg_sales_lag6_MEAN',
'card_id_avg_purchases_lag6_MEAN',
'card_id_active_months_lag6_MEAN',
'card_id_avg_sales_lag12_MEAN',
'card_id_avg_purchases_lag12_MEAN',
'card_id_active_months_lag12_MEAN',]'''

features_to_drop = ['first_active_month','card_id','target','df_temp_purchase_date',
                    'card_id_category_1_COUNT','card_id_category_1_MEAN','hcard_id_subsector_id_dummy_20_SUM'
                   ,'hcard_id_most_recent_sales_range_dummy_A_SUM'
                   ]

drop_improved = []

startScore = 3.676477585740672
total = len(lowfeatures)
for i,lowf in enumerate(lowfeatures):
    print('(%d/%d feature removed : %s ' % (i,total,lowf))
    currentFeatures = features_to_drop + [lowf]
    print(currentFeatures)
    X = train.drop(currentFeatures,axis=1,errors='ignore') 
    y = train['target']
    X_test = test.drop(currentFeatures,axis=1,errors='ignore')

    FOLDs = KFold(n_splits=3, shuffle=True, random_state=100)

    oof_lgb = np.zeros(len(X))
    predictions_lgb = np.zeros(len(X_test))

    features_lgb = list(X.columns)
    feature_importance_df_lgb = pd.DataFrame()

    for fold_, (trn_idx, val_idx) in enumerate(FOLDs.split(X)):
        trn_data = lgb.Dataset(X.iloc[trn_idx], label=y.iloc[trn_idx])
        val_data = lgb.Dataset(X.iloc[val_idx], label=y.iloc[val_idx])

        print("LGB " + str(fold_) + "-" * 50)
        num_round = 10000
        clf = lgb.train(lgb_params, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 50)
        oof_lgb[val_idx] = clf.predict(X.iloc[val_idx], num_iteration=clf.best_iteration)

        fold_importance_df_lgb = pd.DataFrame()
        fold_importance_df_lgb["feature"] = features_lgb
        fold_importance_df_lgb["importance"] = clf.feature_importance()
        fold_importance_df_lgb["fold"] = fold_ + 1
        feature_importance_df_lgb = pd.concat([feature_importance_df_lgb, fold_importance_df_lgb], axis=0)
        predictions_lgb += clf.predict(X_test, num_iteration=clf.best_iteration) / FOLDs.n_splits

    currentScore = np.sqrt(mean_squared_error(oof_lgb, y))
    if currentScore <= startScore:
        startScore = currentScore
        drop_improved.append(lowf)
        print('improved: ' + lowf)
        
    print(currentScore)

print ('final score: ' + str(startScore))
print(drop_improved)
# Out:
# (0/1 feature removed :
# ['first_active_month', 'card_id', 'target', 'df_temp_purchase_date', 'card_id_category_1_COUNT', 'card_id_category_1_MEAN', 'hcard_id_subsector_id_dummy_20_SUM', 'hcard_id_most_recent_sales_range_dummy_A_SUM', 'hcard_id_merchant_group_id_NUNIQUE', 'card_id_active_months_lag3_MEAN', 'card_id_avg_purchases_lag3_MEAN', 'card_id_category_1_mcts_SUM', 'hcard_id_avg_sales_lag12_MEAN', 'hcard_id_numerical_1_MEAN', 'hcard_id_most_recent_sales_range_dummy_D_SUM', '']
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [54]	training's rmse: 3.32109	valid_1's rmse: 3.59402
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [84]	training's rmse: 3.1794	valid_1's rmse: 3.69702
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [43]	training's rmse: 3.30757	valid_1's rmse: 3.74725
# 3.679981499996164
# final score: 3.676477585740672
# []
# Wall time: 31.1 s

# %%
# %%time

import lightgbm as lgb

lgb_params = {"objective" : "regression", "metric" : "rmse", 
               "max_depth": 9, "min_child_samples": 20, 
              "reg_alpha": 1, "reg_lambda": 1,
              "num_leaves" : 64, "learning_rate" : 0.005, 
               "subsample" : 0.8, "colsample_bytree" : 0.8, "num_threads" : 16,"random_seed" : 47,
               "verbosity": -1}

featuresToAdd = [
    'hcard_id_most_recent_sales_range_dummy_A_SUM',
'hcard_id_most_recent_sales_range_dummy_B_SUM',
'hcard_id_most_recent_sales_range_dummy_C_SUM',
'hcard_id_most_recent_sales_range_dummy_D_SUM',
'hcard_id_most_recent_sales_range_dummy_E_SUM',
'hcard_id_most_recent_purchases_range_dummy_A_SUM',
'hcard_id_most_recent_purchases_range_dummy_B_SUM',
'hcard_id_most_recent_purchases_range_dummy_C_SUM',
'hcard_id_most_recent_purchases_range_dummy_D_SUM',
'hcard_id_most_recent_purchases_range_dummy_E_SUM',
'hcard_id_category_4_dummy_N_SUM',
'hcard_id_category_4_dummy_Y_SUM',
'hcard_id_merchant_group_id_COUNT',
'hcard_id_merchant_group_id_NUNIQUE',
'hcard_id_numerical_1_MEAN',
'hcard_id_numerical_2_MEAN',
'hcard_id_category_1_mcts_COUNT',
'hcard_id_category_1_mcts_NUNIQUE',
'hcard_id_category_1_mcts_SUM',
'hcard_id_category_1_mcts_MEAN',
'hcard_id_avg_sales_lag3_MEAN',
'hcard_id_avg_purchases_lag3_MEAN',
'hcard_id_active_months_lag3_MEAN',
'hcard_id_avg_sales_lag6_MEAN',
'hcard_id_avg_purchases_lag6_MEAN',
'hcard_id_active_months_lag6_MEAN',
'hcard_id_avg_sales_lag12_MEAN',
'hcard_id_avg_purchases_lag12_MEAN',
'hcard_id_active_months_lag12_MEAN',
'card_id_most_recent_sales_range_dummy_A_SUM',
'card_id_most_recent_sales_range_dummy_B_SUM',
'card_id_most_recent_sales_range_dummy_C_SUM',
'card_id_most_recent_sales_range_dummy_D_SUM',
'card_id_most_recent_sales_range_dummy_E_SUM',
'card_id_most_recent_purchases_range_dummy_A_SUM',
'card_id_most_recent_purchases_range_dummy_B_SUM',
'card_id_most_recent_purchases_range_dummy_C_SUM',
'card_id_most_recent_purchases_range_dummy_D_SUM',
'card_id_most_recent_purchases_range_dummy_E_SUM',
'card_id_category_4_dummy_N_SUM',
'card_id_category_4_dummy_Y_SUM',
'card_id_merchant_group_id_COUNT',
'card_id_merchant_group_id_NUNIQUE',
'card_id_numerical_1_MEAN',
'card_id_numerical_2_MEAN',
'card_id_category_1_mcts_COUNT',
'card_id_category_1_mcts_NUNIQUE',
'card_id_category_1_mcts_SUM',
'card_id_category_1_mcts_MEAN',
'card_id_avg_sales_lag3_MEAN',
'card_id_avg_purchases_lag3_MEAN',
'card_id_active_months_lag3_MEAN',
'card_id_avg_sales_lag6_MEAN',
'card_id_avg_purchases_lag6_MEAN',
'card_id_active_months_lag6_MEAN',
'card_id_avg_sales_lag12_MEAN',
'card_id_avg_purchases_lag12_MEAN',
'card_id_active_months_lag12_MEAN',]

features_to_drop = ['first_active_month','card_id','target','df_temp_purchase_date',
                    'card_id_category_1_COUNT','card_id_category_1_MEAN','hcard_id_subsector_id_dummy_20_SUM']

drop_improved = []

startScore = 3.6670162046723545
total = len(featuresToAdd)
for i,lowf in enumerate(featuresToAdd):
    print('(%d/%d feature added : %s ' % (i,total,lowf))
    currentFeatures = features_to_drop + featuresToAdd
    currentFeatures.remove(lowf)
    #print(currentFeatures)
    X = train.drop(currentFeatures,axis=1,errors='ignore') 
    y = train['target']
    X_test = test.drop(currentFeatures,axis=1,errors='ignore')

    FOLDs = KFold(n_splits=3, shuffle=True, random_state=100)

    oof_lgb = np.zeros(len(X))
    predictions_lgb = np.zeros(len(X_test))

    features_lgb = list(X.columns)
    feature_importance_df_lgb = pd.DataFrame()

    for fold_, (trn_idx, val_idx) in enumerate(FOLDs.split(X)):
        trn_data = lgb.Dataset(X.iloc[trn_idx], label=y.iloc[trn_idx])
        val_data = lgb.Dataset(X.iloc[val_idx], label=y.iloc[val_idx])

        print("LGB " + str(fold_) + "-" * 50)
        num_round = 10000
        clf = lgb.train(lgb_params, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 50)
        oof_lgb[val_idx] = clf.predict(X.iloc[val_idx], num_iteration=clf.best_iteration)

        fold_importance_df_lgb = pd.DataFrame()
        fold_importance_df_lgb["feature"] = features_lgb
        fold_importance_df_lgb["importance"] = clf.feature_importance()
        fold_importance_df_lgb["fold"] = fold_ + 1
        feature_importance_df_lgb = pd.concat([feature_importance_df_lgb, fold_importance_df_lgb], axis=0)
        predictions_lgb += clf.predict(X_test, num_iteration=clf.best_iteration) / FOLDs.n_splits

    currentScore = np.sqrt(mean_squared_error(oof_lgb, y))
    if currentScore <= startScore:
        startScore = currentScore
        drop_improved.append(lowf)
        print('improved: ' + lowf)
        
    print(currentScore)

print ('final score: ' + str(startScore))
print(drop_improved)
# Out:
# (0/58 feature added : hcard_id_most_recent_sales_range_dummy_A_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34645	valid_1's rmse: 3.58507
# Early stopping, best iteration is:
# [1249]	training's rmse: 3.29486	valid_1's rmse: 3.58363
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30586	valid_1's rmse: 3.68713
# Early stopping, best iteration is:
# [1902]	training's rmse: 3.17193	valid_1's rmse: 3.68265
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27552	valid_1's rmse: 3.73355
# Early stopping, best iteration is:
# [1418]	training's rmse: 3.20233	valid_1's rmse: 3.73133
# improved: hcard_id_most_recent_sales_range_dummy_A_SUM
# 3.6663887535912676
# (1/58 feature added : hcard_id_most_recent_sales_range_dummy_B_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34496	valid_1's rmse: 3.5858
# Early stopping, best iteration is:
# [1606]	training's rmse: 3.23516	valid_1's rmse: 3.58382
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30529	valid_1's rmse: 3.68662
# Early stopping, best iteration is:
# [1825]	training's rmse: 3.17858	valid_1's rmse: 3.68265
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27465	valid_1's rmse: 3.73307
# Early stopping, best iteration is:
# [1301]	training's rmse: 3.21854	valid_1's rmse: 3.73075
# improved: hcard_id_most_recent_sales_range_dummy_B_SUM
# 3.6662493383432615
# (2/58 feature added : hcard_id_most_recent_sales_range_dummy_C_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34328	valid_1's rmse: 3.58623
# Early stopping, best iteration is:
# [1335]	training's rmse: 3.27629	valid_1's rmse: 3.58407
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30449	valid_1's rmse: 3.68728
# [2000]	training's rmse: 3.15687	valid_1's rmse: 3.68253
# Early stopping, best iteration is:
# [1963]	training's rmse: 3.16068	valid_1's rmse: 3.68247
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27603	valid_1's rmse: 3.73368
# Early stopping, best iteration is:
# [1441]	training's rmse: 3.19788	valid_1's rmse: 3.7315
# 3.666525356115887
# (3/58 feature added : hcard_id_most_recent_sales_range_dummy_D_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34457	valid_1's rmse: 3.58497
# Early stopping, best iteration is:
# [1401]	training's rmse: 3.26806	valid_1's rmse: 3.58255
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30576	valid_1's rmse: 3.68734
# Early stopping, best iteration is:
# [1583]	training's rmse: 3.20931	valid_1's rmse: 3.68386
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27493	valid_1's rmse: 3.73352
# Early stopping, best iteration is:
# [1425]	training's rmse: 3.20028	valid_1's rmse: 3.73114
# 3.6663741329525004
# (4/58 feature added : hcard_id_most_recent_sales_range_dummy_E_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34438	valid_1's rmse: 3.585
# Early stopping, best iteration is:
# [1322]	training's rmse: 3.28001	valid_1's rmse: 3.58305
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30539	valid_1's rmse: 3.68704
# Early stopping, best iteration is:
# [1689]	training's rmse: 3.1954	valid_1's rmse: 3.68323
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27586	valid_1's rmse: 3.73409
# Early stopping, best iteration is:
# [1402]	training's rmse: 3.2045	valid_1's rmse: 3.73168
# 3.6665098557903764
# (5/58 feature added : hcard_id_most_recent_purchases_range_dummy_A_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34486	valid_1's rmse: 3.58519
# Early stopping, best iteration is:
# [1338]	training's rmse: 3.27875	valid_1's rmse: 3.58334
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30564	valid_1's rmse: 3.68685
# [2000]	training's rmse: 3.15932	valid_1's rmse: 3.68279
# Early stopping, best iteration is:
# [2051]	training's rmse: 3.15402	valid_1's rmse: 3.68269
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27706	valid_1's rmse: 3.73275
# Early stopping, best iteration is:
# [1350]	training's rmse: 3.21473	valid_1's rmse: 3.73036
# improved: hcard_id_most_recent_purchases_range_dummy_A_SUM
# 3.6659719692483708
# (6/58 feature added : hcard_id_most_recent_purchases_range_dummy_B_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34608	valid_1's rmse: 3.58495
# Early stopping, best iteration is:
# [1333]	training's rmse: 3.28059	valid_1's rmse: 3.58247
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30629	valid_1's rmse: 3.68666
# Early stopping, best iteration is:
# [1874]	training's rmse: 3.17455	valid_1's rmse: 3.68218
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27577	valid_1's rmse: 3.7332
# Early stopping, best iteration is:
# [1468]	training's rmse: 3.19343	valid_1's rmse: 3.73075
# improved: hcard_id_most_recent_purchases_range_dummy_B_SUM
# 3.665651109000402
# (7/58 feature added : hcard_id_most_recent_purchases_range_dummy_C_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34431	valid_1's rmse: 3.58482
# Early stopping, best iteration is:
# [1446]	training's rmse: 3.25969	valid_1's rmse: 3.58246
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30409	valid_1's rmse: 3.68678
# Early stopping, best iteration is:
# [1796]	training's rmse: 3.17978	valid_1's rmse: 3.68209
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.2736	valid_1's rmse: 3.73368
# Early stopping, best iteration is:
# [1383]	training's rmse: 3.20485	valid_1's rmse: 3.73124
# 3.6657869339326656
# (8/58 feature added : hcard_id_most_recent_purchases_range_dummy_D_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34384	valid_1's rmse: 3.58457
# Early stopping, best iteration is:
# [1730]	training's rmse: 3.21737	valid_1's rmse: 3.58189
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30438	valid_1's rmse: 3.68759
# Early stopping, best iteration is:
# [1614]	training's rmse: 3.20263	valid_1's rmse: 3.68371
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27539	valid_1's rmse: 3.73357
# Early stopping, best iteration is:
# [1440]	training's rmse: 3.19651	valid_1's rmse: 3.73127
# 3.6661545555294888
# (9/58 feature added : hcard_id_most_recent_purchases_range_dummy_E_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34464	valid_1's rmse: 3.58487
# Early stopping, best iteration is:
# [1611]	training's rmse: 3.23424	valid_1's rmse: 3.58212
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30505	valid_1's rmse: 3.6877
# [2000]	training's rmse: 3.15905	valid_1's rmse: 3.6837
# Early stopping, best iteration is:
# [2221]	training's rmse: 3.13414	valid_1's rmse: 3.68333
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27517	valid_1's rmse: 3.73331
# Early stopping, best iteration is:
# [1391]	training's rmse: 3.20507	valid_1's rmse: 3.73101
# 3.66601007168109
# (10/58 feature added : hcard_id_category_4_dummy_N_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34297	valid_1's rmse: 3.5847
# Early stopping, best iteration is:
# [1537]	training's rmse: 3.24341	valid_1's rmse: 3.58141
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30503	valid_1's rmse: 3.68716
# [2000]	training's rmse: 3.15894	valid_1's rmse: 3.68273
# Early stopping, best iteration is:
# [2085]	training's rmse: 3.1496	valid_1's rmse: 3.6826
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27518	valid_1's rmse: 3.73361
# Early stopping, best iteration is:
# [1392]	training's rmse: 3.20434	valid_1's rmse: 3.73148
# 3.665694694406374
# (11/58 feature added : hcard_id_category_4_dummy_Y_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34295	valid_1's rmse: 3.58508
# Early stopping, best iteration is:
# [1590]	training's rmse: 3.23576	valid_1's rmse: 3.58244
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30467	valid_1's rmse: 3.68649
# Early stopping, best iteration is:
# [1491]	training's rmse: 3.22012	valid_1's rmse: 3.68342
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27302	valid_1's rmse: 3.73387
# Early stopping, best iteration is:
# [1469]	training's rmse: 3.18994	valid_1's rmse: 3.73142
# 3.6662851851383755
# (12/58 feature added : hcard_id_merchant_group_id_COUNT
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34503	valid_1's rmse: 3.58379
# Early stopping, best iteration is:
# [1330]	training's rmse: 3.27859	valid_1's rmse: 3.58194
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30523	valid_1's rmse: 3.68833
# [2000]	training's rmse: 3.1597	valid_1's rmse: 3.68317
# Early stopping, best iteration is:
# [1999]	training's rmse: 3.15984	valid_1's rmse: 3.68314
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27595	valid_1's rmse: 3.73359
# Early stopping, best iteration is:
# [1363]	training's rmse: 3.21014	valid_1's rmse: 3.73109
# 3.6659168484397866
# (13/58 feature added : hcard_id_merchant_group_id_NUNIQUE
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34519	valid_1's rmse: 3.58438
# Early stopping, best iteration is:
# [1508]	training's rmse: 3.25067	valid_1's rmse: 3.58156
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30438	valid_1's rmse: 3.68868
# Early stopping, best iteration is:
# [1524]	training's rmse: 3.21813	valid_1's rmse: 3.68536
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27627	valid_1's rmse: 3.73417
# Early stopping, best iteration is:
# [1287]	training's rmse: 3.22205	valid_1's rmse: 3.73223
# 3.666920330830981
# (14/58 feature added : hcard_id_numerical_1_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34192	valid_1's rmse: 3.58649
# Early stopping, best iteration is:
# [1335]	training's rmse: 3.2766	valid_1's rmse: 3.58405
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30415	valid_1's rmse: 3.68692
# [2000]	training's rmse: 3.15888	valid_1's rmse: 3.68217
# Early stopping, best iteration is:
# [2136]	training's rmse: 3.14372	valid_1's rmse: 3.68203
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27418	valid_1's rmse: 3.73378
# Early stopping, best iteration is:
# [1478]	training's rmse: 3.1903	valid_1's rmse: 3.7311
# 3.6662344032979974
# (15/58 feature added : hcard_id_numerical_2_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34381	valid_1's rmse: 3.58532
# Early stopping, best iteration is:
# [1338]	training's rmse: 3.27735	valid_1's rmse: 3.58318
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3048	valid_1's rmse: 3.68767
# [2000]	training's rmse: 3.15856	valid_1's rmse: 3.68299
# Early stopping, best iteration is:
# [1966]	training's rmse: 3.1622	valid_1's rmse: 3.68291
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27472	valid_1's rmse: 3.7351
# Early stopping, best iteration is:
# [1331]	training's rmse: 3.21524	valid_1's rmse: 3.73293
# 3.666870251105808
# (16/58 feature added : hcard_id_category_1_mcts_COUNT
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3443	valid_1's rmse: 3.58506
# Early stopping, best iteration is:
# [1331]	training's rmse: 3.27954	valid_1's rmse: 3.58256
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.306	valid_1's rmse: 3.68804
# [2000]	training's rmse: 3.16079	valid_1's rmse: 3.68378
# Early stopping, best iteration is:
# [1951]	training's rmse: 3.16629	valid_1's rmse: 3.6837
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27616	valid_1's rmse: 3.73374
# Early stopping, best iteration is:
# [1348]	training's rmse: 3.21379	valid_1's rmse: 3.73149
# 3.666442266653183
# (17/58 feature added : hcard_id_category_1_mcts_NUNIQUE
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34415	valid_1's rmse: 3.58507
# Early stopping, best iteration is:
# [1405]	training's rmse: 3.26736	valid_1's rmse: 3.58232
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30519	valid_1's rmse: 3.68784
# Early stopping, best iteration is:
# [1886]	training's rmse: 3.17314	valid_1's rmse: 3.68358
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27621	valid_1's rmse: 3.73452
# Early stopping, best iteration is:
# [1462]	training's rmse: 3.19436	valid_1's rmse: 3.73207
# 3.6665217795734413
# (18/58 feature added : hcard_id_category_1_mcts_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34408	valid_1's rmse: 3.58618
# Early stopping, best iteration is:
# [1377]	training's rmse: 3.27178	valid_1's rmse: 3.58419
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3053	valid_1's rmse: 3.68609
# Early stopping, best iteration is:
# [1659]	training's rmse: 3.19906	valid_1's rmse: 3.68234
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27501	valid_1's rmse: 3.7336
# Early stopping, best iteration is:
# [1368]	training's rmse: 3.20862	valid_1's rmse: 3.73129
# 3.6664528470237547
# (19/58 feature added : hcard_id_category_1_mcts_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34259	valid_1's rmse: 3.58433
# Early stopping, best iteration is:
# [1372]	training's rmse: 3.26999	valid_1's rmse: 3.58192
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30623	valid_1's rmse: 3.68668
# [2000]	training's rmse: 3.1593	valid_1's rmse: 3.68201
# Early stopping, best iteration is:
# [2033]	training's rmse: 3.15591	valid_1's rmse: 3.68187
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27482	valid_1's rmse: 3.73389
# Early stopping, best iteration is:
# [1452]	training's rmse: 3.19484	valid_1's rmse: 3.73082
# improved: hcard_id_category_1_mcts_MEAN
# 3.6653943595637797
# (20/58 feature added : hcard_id_avg_sales_lag3_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34394	valid_1's rmse: 3.58615
# Early stopping, best iteration is:
# [1258]	training's rmse: 3.29132	valid_1's rmse: 3.58379
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3043	valid_1's rmse: 3.68765
# Early stopping, best iteration is:
# [1507]	training's rmse: 3.21862	valid_1's rmse: 3.68412
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27483	valid_1's rmse: 3.73368
# Early stopping, best iteration is:
# [1412]	training's rmse: 3.2017	valid_1's rmse: 3.73117
# 3.6668752650705305
# (21/58 feature added : hcard_id_avg_purchases_lag3_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34512	valid_1's rmse: 3.58381
# Early stopping, best iteration is:
# [1333]	training's rmse: 3.2795	valid_1's rmse: 3.5818
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30517	valid_1's rmse: 3.68805
# Early stopping, best iteration is:
# [1651]	training's rmse: 3.20127	valid_1's rmse: 3.68478
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27426	valid_1's rmse: 3.73399
# Early stopping, best iteration is:
# [1553]	training's rmse: 3.17788	valid_1's rmse: 3.73103
# 3.666399850637395
# (22/58 feature added : hcard_id_active_months_lag3_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3446	valid_1's rmse: 3.58604
# Early stopping, best iteration is:
# [1494]	training's rmse: 3.25216	valid_1's rmse: 3.58301
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30573	valid_1's rmse: 3.6879
# Early stopping, best iteration is:
# [1860]	training's rmse: 3.17647	valid_1's rmse: 3.68339
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27663	valid_1's rmse: 3.73409
# Early stopping, best iteration is:
# [1366]	training's rmse: 3.21038	valid_1's rmse: 3.73177
# 3.6665785200482177
# (23/58 feature added : hcard_id_avg_sales_lag6_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34404	valid_1's rmse: 3.58526
# Early stopping, best iteration is:
# [1329]	training's rmse: 3.27955	valid_1's rmse: 3.58272
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30399	valid_1's rmse: 3.68812
# Early stopping, best iteration is:
# [1801]	training's rmse: 3.17967	valid_1's rmse: 3.68364
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27453	valid_1's rmse: 3.73429
# Early stopping, best iteration is:
# [1461]	training's rmse: 3.19259	valid_1's rmse: 3.7316
# 3.666510983272497
# (24/58 feature added : hcard_id_avg_purchases_lag6_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.344	valid_1's rmse: 3.58405
# Early stopping, best iteration is:
# [1515]	training's rmse: 3.24658	valid_1's rmse: 3.58072
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30357	valid_1's rmse: 3.68711
# Early stopping, best iteration is:
# [1802]	training's rmse: 3.18141	valid_1's rmse: 3.68253
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27585	valid_1's rmse: 3.7335
# Early stopping, best iteration is:
# [1446]	training's rmse: 3.19641	valid_1's rmse: 3.73106
# improved: hcard_id_avg_purchases_lag6_MEAN
# 3.665304087852785
# (25/58 feature added : hcard_id_active_months_lag6_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34436	valid_1's rmse: 3.58434
# Early stopping, best iteration is:
# [1508]	training's rmse: 3.25033	valid_1's rmse: 3.58161
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30672	valid_1's rmse: 3.6862
# Early stopping, best iteration is:
# [1664]	training's rmse: 3.19938	valid_1's rmse: 3.68247
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27599	valid_1's rmse: 3.73446
# Early stopping, best iteration is:
# [1453]	training's rmse: 3.19548	valid_1's rmse: 3.73226
# 3.6659832032188557
# (26/58 feature added : hcard_id_avg_sales_lag12_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34454	valid_1's rmse: 3.58512
# Early stopping, best iteration is:
# [1341]	training's rmse: 3.27752	valid_1's rmse: 3.5831
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30419	valid_1's rmse: 3.68684
# Early stopping, best iteration is:
# [1655]	training's rmse: 3.19843	valid_1's rmse: 3.68306
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27448	valid_1's rmse: 3.73219
# Early stopping, best iteration is:
# [1474]	training's rmse: 3.1913	valid_1's rmse: 3.72926
# 3.6656446580225897
# (27/58 feature added : hcard_id_avg_purchases_lag12_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34413	valid_1's rmse: 3.58463
# Early stopping, best iteration is:
# [1474]	training's rmse: 3.25471	valid_1's rmse: 3.58192
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30483	valid_1's rmse: 3.68742
# Early stopping, best iteration is:
# [1525]	training's rmse: 3.21643	valid_1's rmse: 3.68408
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27587	valid_1's rmse: 3.73374
# Early stopping, best iteration is:
# [1380]	training's rmse: 3.20701	valid_1's rmse: 3.73126
# 3.6662819369502255
# (28/58 feature added : hcard_id_active_months_lag12_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34105	valid_1's rmse: 3.58431
# Early stopping, best iteration is:
# [1473]	training's rmse: 3.24771	valid_1's rmse: 3.58226
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30311	valid_1's rmse: 3.6863
# Early stopping, best iteration is:
# [1776]	training's rmse: 3.18096	valid_1's rmse: 3.68223
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27603	valid_1's rmse: 3.73212
# Early stopping, best iteration is:
# [1433]	training's rmse: 3.19928	valid_1's rmse: 3.72987
# 3.6653041572941043
# (29/58 feature added : card_id_most_recent_sales_range_dummy_A_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34305	valid_1's rmse: 3.58676
# Early stopping, best iteration is:
# [1463]	training's rmse: 3.25655	valid_1's rmse: 3.58375
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30561	valid_1's rmse: 3.68633
# [2000]	training's rmse: 3.15923	valid_1's rmse: 3.68145
# Early stopping, best iteration is:
# [1950]	training's rmse: 3.16503	valid_1's rmse: 3.68141
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27415	valid_1's rmse: 3.73557
# Early stopping, best iteration is:
# [1444]	training's rmse: 3.19604	valid_1's rmse: 3.73297
# 3.6665660839745318
# (30/58 feature added : card_id_most_recent_sales_range_dummy_B_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3443	valid_1's rmse: 3.58428
# Early stopping, best iteration is:
# [1371]	training's rmse: 3.27262	valid_1's rmse: 3.58202
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30769	valid_1's rmse: 3.68689
# Early stopping, best iteration is:
# [1702]	training's rmse: 3.19648	valid_1's rmse: 3.68319
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27467	valid_1's rmse: 3.73417
# Early stopping, best iteration is:
# [1379]	training's rmse: 3.20668	valid_1's rmse: 3.73116
# 3.665981368232342
# (31/58 feature added : card_id_most_recent_sales_range_dummy_C_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34573	valid_1's rmse: 3.58572
# Early stopping, best iteration is:
# [1403]	training's rmse: 3.26795	valid_1's rmse: 3.58324
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30508	valid_1's rmse: 3.68725
# Early stopping, best iteration is:
# [1825]	training's rmse: 3.17884	valid_1's rmse: 3.68285
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27514	valid_1's rmse: 3.73411
# Early stopping, best iteration is:
# [1368]	training's rmse: 3.2095	valid_1's rmse: 3.73161
# 3.6664205096942295
# (32/58 feature added : card_id_most_recent_sales_range_dummy_D_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34515	valid_1's rmse: 3.58463
# Early stopping, best iteration is:
# [1344]	training's rmse: 3.27746	valid_1's rmse: 3.58254
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30584	valid_1's rmse: 3.68679
# [2000]	training's rmse: 3.16074	valid_1's rmse: 3.68255
# Early stopping, best iteration is:
# [2149]	training's rmse: 3.14402	valid_1's rmse: 3.68211
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27372	valid_1's rmse: 3.73505
# Early stopping, best iteration is:
# [1410]	training's rmse: 3.20165	valid_1's rmse: 3.73243
# 3.6662245127061213
# (33/58 feature added : card_id_most_recent_sales_range_dummy_E_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3439	valid_1's rmse: 3.58563
# Early stopping, best iteration is:
# [1497]	training's rmse: 3.25103	valid_1's rmse: 3.58282
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30584	valid_1's rmse: 3.68741
# Early stopping, best iteration is:
# [1371]	training's rmse: 3.24139	valid_1's rmse: 3.68507
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27534	valid_1's rmse: 3.73407
# Early stopping, best iteration is:
# [1488]	training's rmse: 3.1889	valid_1's rmse: 3.73148
# 3.666985309867816
# (34/58 feature added : card_id_most_recent_purchases_range_dummy_A_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3441	valid_1's rmse: 3.58581
# Early stopping, best iteration is:
# [1306]	training's rmse: 3.28361	valid_1's rmse: 3.58335
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30485	valid_1's rmse: 3.68748
# Early stopping, best iteration is:
# [1901]	training's rmse: 3.17109	valid_1's rmse: 3.68352
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27353	valid_1's rmse: 3.73446
# Early stopping, best iteration is:
# [1360]	training's rmse: 3.20865	valid_1's rmse: 3.73209
# 3.6668431220926307
# (35/58 feature added : card_id_most_recent_purchases_range_dummy_B_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34295	valid_1's rmse: 3.58497
# Early stopping, best iteration is:
# [1271]	training's rmse: 3.28846	valid_1's rmse: 3.58333
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3056	valid_1's rmse: 3.68708
# Early stopping, best iteration is:
# [1446]	training's rmse: 3.22904	valid_1's rmse: 3.68388
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27572	valid_1's rmse: 3.73467
# Early stopping, best iteration is:
# [1396]	training's rmse: 3.20471	valid_1's rmse: 3.73182
# 3.6668667355640188
# (36/58 feature added : card_id_most_recent_purchases_range_dummy_C_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34319	valid_1's rmse: 3.58495
# Early stopping, best iteration is:
# [1389]	training's rmse: 3.2681	valid_1's rmse: 3.583
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30546	valid_1's rmse: 3.68648
# Early stopping, best iteration is:
# [1586]	training's rmse: 3.20897	valid_1's rmse: 3.68302
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27443	valid_1's rmse: 3.73352
# Early stopping, best iteration is:
# [1434]	training's rmse: 3.19728	valid_1's rmse: 3.73078
# 3.6661174011637705
# (37/58 feature added : card_id_most_recent_purchases_range_dummy_D_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3442	valid_1's rmse: 3.58413
# Early stopping, best iteration is:
# [1366]	training's rmse: 3.27347	valid_1's rmse: 3.58161
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30586	valid_1's rmse: 3.6868
# Early stopping, best iteration is:
# [1485]	training's rmse: 3.22383	valid_1's rmse: 3.68392
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27356	valid_1's rmse: 3.73589
# Early stopping, best iteration is:
# [1443]	training's rmse: 3.19644	valid_1's rmse: 3.73354
# 3.666899465357419
# (38/58 feature added : card_id_most_recent_purchases_range_dummy_E_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34333	valid_1's rmse: 3.58593
# Early stopping, best iteration is:
# [1353]	training's rmse: 3.2743	valid_1's rmse: 3.58315
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30667	valid_1's rmse: 3.68728
# Early stopping, best iteration is:
# [1566]	training's rmse: 3.21217	valid_1's rmse: 3.6843
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27386	valid_1's rmse: 3.73509
# Early stopping, best iteration is:
# [1400]	training's rmse: 3.20174	valid_1's rmse: 3.73288
# 3.6673067299918407
# (39/58 feature added : card_id_category_4_dummy_N_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34343	valid_1's rmse: 3.58425
# Early stopping, best iteration is:
# [1404]	training's rmse: 3.26642	valid_1's rmse: 3.58146
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30496	valid_1's rmse: 3.68574
# Early stopping, best iteration is:
# [1843]	training's rmse: 3.17676	valid_1's rmse: 3.68146
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27506	valid_1's rmse: 3.73463
# Early stopping, best iteration is:
# [1422]	training's rmse: 3.20049	valid_1's rmse: 3.73194
# 3.6654857415618873
# (40/58 feature added : card_id_category_4_dummy_Y_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3441	valid_1's rmse: 3.58498
# Early stopping, best iteration is:
# [1457]	training's rmse: 3.25893	valid_1's rmse: 3.58224
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30627	valid_1's rmse: 3.68625
# [2000]	training's rmse: 3.15909	valid_1's rmse: 3.68174
# Early stopping, best iteration is:
# [2190]	training's rmse: 3.13776	valid_1's rmse: 3.68129
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27382	valid_1's rmse: 3.73497
# Early stopping, best iteration is:
# [1441]	training's rmse: 3.19587	valid_1's rmse: 3.73264
# 3.66592005116485
# (41/58 feature added : card_id_merchant_group_id_COUNT
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34435	valid_1's rmse: 3.58455
# Early stopping, best iteration is:
# [1572]	training's rmse: 3.23941	valid_1's rmse: 3.58177
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30538	valid_1's rmse: 3.68703
# Early stopping, best iteration is:
# [1539]	training's rmse: 3.2149	valid_1's rmse: 3.68369
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27386	valid_1's rmse: 3.73437
# Early stopping, best iteration is:
# [1372]	training's rmse: 3.20638	valid_1's rmse: 3.73213
# 3.666399570804053
# (42/58 feature added : card_id_merchant_group_id_NUNIQUE
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3467	valid_1's rmse: 3.5857
# Early stopping, best iteration is:
# [1622]	training's rmse: 3.23561	valid_1's rmse: 3.58284
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30541	valid_1's rmse: 3.6875
# Early stopping, best iteration is:
# [1280]	training's rmse: 3.25581	valid_1's rmse: 3.6849
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27511	valid_1's rmse: 3.7353
# Early stopping, best iteration is:
# [1374]	training's rmse: 3.20791	valid_1's rmse: 3.73283
# 3.667390472598673
# (43/58 feature added : card_id_numerical_1_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34385	valid_1's rmse: 3.58524
# Early stopping, best iteration is:
# [1489]	training's rmse: 3.25407	valid_1's rmse: 3.58274
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30571	valid_1's rmse: 3.68645
# [2000]	training's rmse: 3.15731	valid_1's rmse: 3.68179
# Early stopping, best iteration is:
# [2153]	training's rmse: 3.14026	valid_1's rmse: 3.68149
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27444	valid_1's rmse: 3.73571
# Early stopping, best iteration is:
# [1399]	training's rmse: 3.20287	valid_1's rmse: 3.73301
# 3.666276382721418
# (44/58 feature added : card_id_numerical_2_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34336	valid_1's rmse: 3.58534
# Early stopping, best iteration is:
# [1307]	training's rmse: 3.28457	valid_1's rmse: 3.58284
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3048	valid_1's rmse: 3.68716
# Early stopping, best iteration is:
# [1297]	training's rmse: 3.25063	valid_1's rmse: 3.68458
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27461	valid_1's rmse: 3.73609
# Early stopping, best iteration is:
# [1369]	training's rmse: 3.20776	valid_1's rmse: 3.73374
# 3.667594679525072
# (45/58 feature added : card_id_category_1_mcts_COUNT
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34579	valid_1's rmse: 3.58503
# Early stopping, best iteration is:
# [1434]	training's rmse: 3.26257	valid_1's rmse: 3.58206
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30414	valid_1's rmse: 3.68633
# Early stopping, best iteration is:
# [1934]	training's rmse: 3.16483	valid_1's rmse: 3.68259
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27358	valid_1's rmse: 3.73491
# Early stopping, best iteration is:
# [1285]	training's rmse: 3.22129	valid_1's rmse: 3.73274
# 3.666331990571038
# (46/58 feature added : card_id_category_1_mcts_NUNIQUE
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34572	valid_1's rmse: 3.58405
# Early stopping, best iteration is:
# [1522]	training's rmse: 3.24792	valid_1's rmse: 3.58133
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30628	valid_1's rmse: 3.68666
# Early stopping, best iteration is:
# [1767]	training's rmse: 3.18589	valid_1's rmse: 3.68277
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27609	valid_1's rmse: 3.73433
# Early stopping, best iteration is:
# [1401]	training's rmse: 3.20344	valid_1's rmse: 3.73192
# 3.6658750413472427
# (47/58 feature added : card_id_category_1_mcts_SUM
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34523	valid_1's rmse: 3.5849
# Early stopping, best iteration is:
# [1465]	training's rmse: 3.25721	valid_1's rmse: 3.58196
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30479	valid_1's rmse: 3.68764
# Early stopping, best iteration is:
# [1803]	training's rmse: 3.18206	valid_1's rmse: 3.68357
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27485	valid_1's rmse: 3.73545
# Early stopping, best iteration is:
# [1441]	training's rmse: 3.19732	valid_1's rmse: 3.73269
# 3.6666067233774857
# (48/58 feature added : card_id_category_1_mcts_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34601	valid_1's rmse: 3.58383
# Early stopping, best iteration is:
# [1337]	training's rmse: 3.27914	valid_1's rmse: 3.58163
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30389	valid_1's rmse: 3.68647
# [2000]	training's rmse: 3.15526	valid_1's rmse: 3.68147
# Early stopping, best iteration is:
# [2067]	training's rmse: 3.1476	valid_1's rmse: 3.6813
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27479	valid_1's rmse: 3.73421
# Early stopping, best iteration is:
# [1344]	training's rmse: 3.21146	valid_1's rmse: 3.73164
# 3.665388132729104
# (49/58 feature added : card_id_avg_sales_lag3_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34427	valid_1's rmse: 3.58518
# Early stopping, best iteration is:
# [1596]	training's rmse: 3.23665	valid_1's rmse: 3.58238
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30421	valid_1's rmse: 3.68703
# Early stopping, best iteration is:
# [1897]	training's rmse: 3.16873	valid_1's rmse: 3.68239
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27272	valid_1's rmse: 3.73555
# Early stopping, best iteration is:
# [1399]	training's rmse: 3.20123	valid_1's rmse: 3.73304
# 3.6664733116521515
# (50/58 feature added : card_id_avg_purchases_lag3_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34318	valid_1's rmse: 3.58475
# Early stopping, best iteration is:
# [1468]	training's rmse: 3.25446	valid_1's rmse: 3.58215
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30433	valid_1's rmse: 3.68714
# [2000]	training's rmse: 3.15721	valid_1's rmse: 3.68261
# Early stopping, best iteration is:
# [2141]	training's rmse: 3.14194	valid_1's rmse: 3.68218
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27296	valid_1's rmse: 3.73471
# Early stopping, best iteration is:
# [1443]	training's rmse: 3.1946	valid_1's rmse: 3.73226
# 3.666061696175113
# (51/58 feature added : card_id_active_months_lag3_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34343	valid_1's rmse: 3.58421
# Early stopping, best iteration is:
# [1353]	training's rmse: 3.274	valid_1's rmse: 3.58123
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30559	valid_1's rmse: 3.68822
# [2000]	training's rmse: 3.15997	valid_1's rmse: 3.68375
# Early stopping, best iteration is:
# [2242]	training's rmse: 3.13247	valid_1's rmse: 3.6834
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27363	valid_1's rmse: 3.73483
# Early stopping, best iteration is:
# [1415]	training's rmse: 3.20008	valid_1's rmse: 3.7323
# 3.666180678089684
# (52/58 feature added : card_id_avg_sales_lag6_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34496	valid_1's rmse: 3.58499
# Early stopping, best iteration is:
# [1649]	training's rmse: 3.22681	valid_1's rmse: 3.58248
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30534	valid_1's rmse: 3.68672
# [2000]	training's rmse: 3.1597	valid_1's rmse: 3.68225
# Early stopping, best iteration is:
# [2107]	training's rmse: 3.1478	valid_1's rmse: 3.68211
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27348	valid_1's rmse: 3.73456
# Early stopping, best iteration is:
# [1395]	training's rmse: 3.20366	valid_1's rmse: 3.73225
# 3.666141926966456
# (53/58 feature added : card_id_avg_purchases_lag6_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.3446	valid_1's rmse: 3.58571
# Early stopping, best iteration is:
# [1492]	training's rmse: 3.25181	valid_1's rmse: 3.58261
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30693	valid_1's rmse: 3.68655
# [2000]	training's rmse: 3.15945	valid_1's rmse: 3.68219
# Early stopping, best iteration is:
# [2130]	training's rmse: 3.14525	valid_1's rmse: 3.68203
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27292	valid_1's rmse: 3.73577
# Early stopping, best iteration is:
# [1407]	training's rmse: 3.20126	valid_1's rmse: 3.73301
# 3.6664141497438
# (54/58 feature added : card_id_active_months_lag6_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34345	valid_1's rmse: 3.58519
# Early stopping, best iteration is:
# [1600]	training's rmse: 3.23475	valid_1's rmse: 3.58218
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30557	valid_1's rmse: 3.68712
# [2000]	training's rmse: 3.15829	valid_1's rmse: 3.68247
# Early stopping, best iteration is:
# [2215]	training's rmse: 3.13371	valid_1's rmse: 3.68218
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.2742	valid_1's rmse: 3.73447
# Early stopping, best iteration is:
# [1392]	training's rmse: 3.20349	valid_1's rmse: 3.73222
# 3.6660566160134374
# (55/58 feature added : card_id_avg_sales_lag12_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34483	valid_1's rmse: 3.58545
# Early stopping, best iteration is:
# [1550]	training's rmse: 3.24372	valid_1's rmse: 3.58249
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30499	valid_1's rmse: 3.68791
# [2000]	training's rmse: 3.15786	valid_1's rmse: 3.68339
# Early stopping, best iteration is:
# [2025]	training's rmse: 3.15511	valid_1's rmse: 3.68336
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.2744	valid_1's rmse: 3.73588
# Early stopping, best iteration is:
# [1234]	training's rmse: 3.23086	valid_1's rmse: 3.7341
# 3.6671889073151873
# (56/58 feature added : card_id_avg_purchases_lag12_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34402	valid_1's rmse: 3.58441
# Early stopping, best iteration is:
# [1500]	training's rmse: 3.24954	valid_1's rmse: 3.58236
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30549	valid_1's rmse: 3.6869
# [2000]	training's rmse: 3.15974	valid_1's rmse: 3.68204
# Early stopping, best iteration is:
# [2008]	training's rmse: 3.15882	valid_1's rmse: 3.68203
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27505	valid_1's rmse: 3.73542
# Early stopping, best iteration is:
# [1458]	training's rmse: 3.19547	valid_1's rmse: 3.73262
# 3.666202684699302
# (57/58 feature added : card_id_active_months_lag12_MEAN
# LGB 0--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.34433	valid_1's rmse: 3.5847
# Early stopping, best iteration is:
# [1547]	training's rmse: 3.24347	valid_1's rmse: 3.58219
# LGB 1--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.30555	valid_1's rmse: 3.68738
# Early stopping, best iteration is:
# [1538]	training's rmse: 3.2147	valid_1's rmse: 3.68394
# LGB 2--------------------------------------------------
# Training until validation scores don't improve for 50 rounds.
# [1000]	training's rmse: 3.27495	valid_1's rmse: 3.73416
# Early stopping, best iteration is:
# [1353]	training's rmse: 3.21113	valid_1's rmse: 3.73204
# 3.666589249436439
# final score: 3.665304087852785
# ['hcard_id_most_recent_sales_range_dummy_A_SUM', 'hcard_id_most_recent_sales_range_dummy_B_SUM', 'hcard_id_most_recent_purchases_range_dummy_A_SUM', 'hcard_id_most_recent_purchases_range_dummy_B_SUM', 'hcard_id_category_1_mcts_MEAN', 'hcard_id_avg_purchases_lag6_MEAN']
# Wall time: 3h 20min 18s

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cols = (feature_importance_df_lgb[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df_lgb.loc[feature_importance_df_lgb.feature.isin(cols)]

plt.figure(figsize=(14,65))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')
# Out:
# c:\users\dani\appdata\local\programs\python\python36\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# %%time

import lightgbm as lgb




lgb_params = {"objective" : ["regression"], "metric" : ["rmse"], 
               "max_depth": [9], "min_child_samples": [60], 
              "reg_alpha": [1], "reg_lambda": [1],
              "num_leaves" : [300], "learning_rate" : [0.005], 
               "subsample" : [.9], "colsample_bytree" : [.9], "num_threads" : [16],"random_seed" : [47],
              "n_estimators" : [100],
               "verbosity": [0]}

lgb1 = lgb.LGBMRegressor()

xgb_grid = GridSearchCV(lgb1,
                        lgb_params,
                        cv = 2,
                        n_jobs = 5,
                        verbose=10)

xgb_grid.fit(X,y)
print(xgb_grid.best_score_)
print(xgb_grid.best_params_)
# Out:
# Fitting 2 folds for each of 5 candidates, totalling 10 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   3 out of  10 | elapsed:   51.6s remaining:  2.0min
# [Parallel(n_jobs=5)]: Done   5 out of  10 | elapsed:   52.7s remaining:   52.7s
# [Parallel(n_jobs=5)]: Done   7 out of  10 | elapsed:  1.7min remaining:   43.6s
# [Parallel(n_jobs=5)]: Done  10 out of  10 | elapsed:  1.7min finished
# 0.0529333340643984
# {'colsample_bytree': 0.9, 'learning_rate': 0.005, 'max_depth': 9, 'metric': 'rmse', 'min_child_samples': 60, 'n_estimators': 100, 'num_leaves': 300, 'num_threads': 16, 'objective': 'regression', 'random_seed': 47, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.9, 'verbosity': 0}
# Wall time: 2min 4s

# %%
feature_importance_df_lgb.sort_values(['importance','fold']).to_csv(root + '/fi.csv', index=False)

# %%
predicted_lgbm = pd.DataFrame()
predicted_lgbm['card_id'] = test['card_id']
predicted_lgbm['target'] = predictions_lgb
predicted_lgbm[['card_id', 'target']] = predicted_lgbm[['card_id', 'target']]
#predicted.to_csv(root + '/submission.csv', index=False,quoting=csv.QUOTE_NONNUMERIC)

predicted_lgbm.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -2.050430
# 1  C_ID_130fd0cbdd -0.339088
# 2  C_ID_b709037bc5 -0.856636
# 3  C_ID_d27d835a9f -0.122110
# 4  C_ID_2b5e3df5c2 -1.195351

# %%
predicted_lgbm.to_csv(root + '/submission_lgbm_all.csv', index=False)

# %%
# %%time

import catboost as cb

FOLDs = KFold(n_splits=10, shuffle=True, random_state=100)

oof_cb = np.zeros(len(X))
predictions_cb = np.zeros(len(X_test))

for n_fold, (trn_idx, val_idx) in enumerate(FOLDs.split(X, y)):
    X_train, y_train = X.iloc[trn_idx], y.iloc[trn_idx]
    X_valid, y_valid = X.iloc[val_idx], y.iloc[val_idx]
    
    # CatBoost Regressor estimator
    model = cb.CatBoostRegressor(
        learning_rate = 0.03,
        iterations = 1000,
        eval_metric = 'RMSE',
        allow_writing_files = False,
        od_type = 'Iter',
        bagging_temperature = 0.2,
        depth = 10,
        od_wait = 20,
        silent = True,
        thread_count=16
    )
    
    # Fit
    model.fit(
        X_train, y_train,
        eval_set=[(X_train, y_train), (X_valid, y_valid)],
        verbose=None,
        early_stopping_rounds=100
    )
    
    print("CB " + str(n_fold) + "-" * 100)
    
    oof_cb[val_idx] = model.predict(X_valid)
    test_preds = model.predict(X_test)
    predictions_cb += test_preds / FOLDs.n_splits

print(np.sqrt(mean_squared_error(oof_cb, y)))
# Out:
# CB 0----------------------------------------------------------------------------------------------------
# CB 1----------------------------------------------------------------------------------------------------
# CB 2----------------------------------------------------------------------------------------------------
# CB 3----------------------------------------------------------------------------------------------------
# CB 4----------------------------------------------------------------------------------------------------
# CB 5----------------------------------------------------------------------------------------------------
# CB 6----------------------------------------------------------------------------------------------------
# CB 7----------------------------------------------------------------------------------------------------
# CB 8----------------------------------------------------------------------------------------------------
# CB 9----------------------------------------------------------------------------------------------------
# 3.6569717108558923
# Wall time: 1h 56min 51s

# %%
type(oof_cb)
oof_cb[0]
# Out:
# -0.20350228512537855

# %%
predicted_cb = pd.DataFrame()
predicted_cb['card_id'] = test['card_id']
predicted_cb['target'] = predictions_cb
predicted_cb[['card_id', 'target']] = predicted_cb[['card_id', 'target']]
predicted_cb.to_csv(root + '/submission_cb.csv', index=False)

# %%
# %%time

xgb_params = {'eta': 0.03, 'max_depth': 7, 'subsample': 0.8, 'colsample_bytree': 0.8, 
          'objective': 'reg:linear', 'eval_metric': 'rmse','random_state':'7', 'nthread':'16', 'min_child_weight':'4', 'silent':1}

FOLDs = KFold(n_splits=15, shuffle=True, random_state=71)

oof_xgb = np.zeros(len(X))
predictions_xgb = np.zeros(len(X_test))

for fold_, (trn_idx, val_idx) in enumerate(FOLDs.split(X)):
    trn_data = xgb.DMatrix(data=X.iloc[trn_idx], label=y.iloc[trn_idx])
    val_data = xgb.DMatrix(data=X.iloc[val_idx], label=y.iloc[val_idx])
    watchlist = [(trn_data, 'train'), (val_data, 'valid')]
    print("XGB " + str(fold_) + "-" * 100)
    num_round = 10000
    xgb_model = xgb.train(xgb_params, trn_data, num_round, watchlist, early_stopping_rounds=100, verbose_eval=1000)
    oof_xgb[val_idx] = xgb_model.predict(xgb.DMatrix(X.iloc[val_idx]), ntree_limit=xgb_model.best_ntree_limit+100)

    predictions_xgb += xgb_model.predict(xgb.DMatrix(X_test), ntree_limit=xgb_model.best_ntree_limit+100) / FOLDs.n_splits

    print(np.sqrt(mean_squared_error(oof_xgb, y)))
# Out:
# XGB 0----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.93686	valid-rmse:3.92202
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [174]	train-rmse:3.3625	valid-rmse:3.65201
#
# 3.8575799797552563
# XGB 1----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.93087	valid-rmse:4.0029
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [174]	train-rmse:3.35391	valid-rmse:3.71869
#
# 3.843429485484925
# XGB 2----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.93924	valid-rmse:3.89417
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [413]	train-rmse:3.19682	valid-rmse:3.59511
#
# 3.8286858681180713
# XGB 3----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.92299	valid-rmse:4.12314
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [370]	train-rmse:3.19931	valid-rmse:3.8062
#
# 3.811796750410037
# XGB 4----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.94663	valid-rmse:3.78659
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [435]	train-rmse:3.17579	valid-rmse:3.51564
#
# 3.798795144110103
# XGB 5----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.93306	valid-rmse:3.98324
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [308]	train-rmse:3.25416	valid-rmse:3.6863
#
# 3.7835483573009507
# XGB 6----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.92838	valid-rmse:4.04334
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [235]	train-rmse:3.30519	valid-rmse:3.7654
#
# 3.769321520745985
# XGB 7----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.93366	valid-rmse:3.97082
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [238]	train-rmse:3.30274	valid-rmse:3.70553
#
# 3.756327578550446
# XGB 8----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.94754	valid-rmse:3.78335
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [454]	train-rmse:3.18097	valid-rmse:3.52553
#
# 3.744506515473881
# XGB 9----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.93865	valid-rmse:3.90014
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [326]	train-rmse:3.24656	valid-rmse:3.60681
#
# 3.729590907639718
# XGB 10----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.93677	valid-rmse:3.93357
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [349]	train-rmse:3.21523	valid-rmse:3.70529
#
# 3.7189375100198787
# XGB 11----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.93105	valid-rmse:4.01557
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [283]	train-rmse:3.26324	valid-rmse:3.70621
#
# 3.7026009992213775
# XGB 12----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.93798	valid-rmse:3.91709
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [440]	train-rmse:3.18405	valid-rmse:3.62992
#
# 3.687933253301692
# XGB 13----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.94224	valid-rmse:3.84525
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [285]	train-rmse:3.27697	valid-rmse:3.5837
#
# 3.674962692694062
# XGB 14----------------------------------------------------------------------------------------------------
# [0]	train-rmse:3.93563	valid-rmse:3.94118
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [396]	train-rmse:3.21034	valid-rmse:3.66093
#
# 3.660689952233447
# Wall time: 1h 9min 1s

# %%
predicted_xgb = pd.DataFrame()
predicted_xgb['card_id'] = test['card_id']
predicted_xgb['target'] = predictions_xgb
predicted_xgb[['card_id', 'target']] = predicted_xgb[['card_id', 'target']]
predicted_xgb.to_csv(root + '/submission_xgb.csv', index=False)
#predicted.to_csv(root + '/submission.csv', index=False,quoting=csv.QUOTE_NONNUMERIC)

predicted_xgb.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -2.486440
# 1  C_ID_130fd0cbdd -0.812535
# 2  C_ID_b709037bc5 -0.944142
# 3  C_ID_d27d835a9f -0.062173
# 4  C_ID_2b5e3df5c2 -1.149013

# %%
from scipy.optimize import minimize

def find_best_weight(preds, target):
    def _validate_func(weights):
        ''' scipy minimize will pass the weights as a numpy array '''
        final_prediction = 0
        for weight, prediction in zip(weights, preds):
                final_prediction += weight * prediction
        return np.sqrt(mean_squared_error(final_prediction, target))

    #the algorithms need a starting value, right not we chose 0.5 for all weights
    #its better to choose many random starting points and run minimize a few times
    starting_values = [0.5]*len(preds)

    #adding constraints and a different solver as suggested by user 16universe
    #https://kaggle2.blob.core.windows.net/forum-message-attachments/75655/2393/otto%20model%20weights.pdf?sv=2012-02-12&se=2015-05-03T21%3A22%3A17Z&sr=b&sp=r&sig=rkeA7EJC%2BiQ%2FJ%2BcMpcA4lYQLFh6ubNqs2XAkGtFsAv0%3D
    cons = ({'type':'eq','fun':lambda w: 1-sum(w)})
    #our weights are bound between 0 and 1
    bounds = [(0, 1)] * len(preds)
    
    res = minimize(_validate_func, starting_values, method='Nelder-Mead', bounds=bounds, constraints=cons)
    
    print('Ensemble Score: {best_score}'.format(best_score=(1-res['fun'])))
    print('Best Weights: {weights}'.format(weights=res['x']))
    
    return res

print('lgb', np.sqrt(mean_squared_error(oof_lgb, y)))
print('xgb', np.sqrt(mean_squared_error(oof_xgb, y)))
print('cb', np.sqrt(mean_squared_error(oof_cb, y)))

#res = find_best_weight([oof_lgb, oof_cb], y)
res = find_best_weight([oof_lgb, oof_xgb], y)
#res = find_best_weight([oof_cb, oof_xgb], y)
#res = find_best_weight([oof_lgb, oof_xgb, oof_cb], y)
# Out:
# lgb 3.652639380209719
# xgb 3.660689952233447
# cb 3.6569717108558923
# c:\users\dani\appdata\local\programs\python\python36\lib\site-packages\scipy\optimize\_minimize.py:518: RuntimeWarning: Method Nelder-Mead cannot handle constraints nor bounds.
#   RuntimeWarning)
# Ensemble Score: -2.6507326433966902
# Best Weights: [0.75440485 0.29315486]

# %%
total_sum = 0.75440485  * oof_lgb + 0.29315486 * oof_xgb
print("CV score: {:<8.5f}".format(np.sqrt(mean_squared_error(total_sum, y))))

sub_df = pd.read_csv(root + '/sample_submission.csv')
sub_df["target"] = 0.75440485 * predictions_lgb + 0.29315486 * predictions_xgb
sub_df.to_csv(root + '/submission_ensemble_lgb_xgb3.csv', index=False)
# Out:
# CV score: 3.65073

# %% [raw]
# # stacking
#
# from sklearn.linear_model import Ridge
# from sklearn.model_selection import RepeatedKFold
# train_stack = np.vstack([oof_cb,oof_lgb,oof_xgb]).transpose()
# test_stack = np.vstack([predictions_cb,predictions_lgb,predictions_xgb]).transpose()
#
# folds = RepeatedKFold(n_splits=15,n_repeats=20,random_state=4520)
# oof_stack = np.zeros(train_stack.shape[0])
# predictions_stack = np.zeros(test_stack.shape[0])
#
# for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_stack, y)):
#     print("fold n°{}".format(fold_))
#     trn_data, trn_y = train_stack[trn_idx], y.iloc[trn_idx].values
#     val_data, val_y = train_stack[val_idx], y.iloc[val_idx].values
#
#     print("-" * 10 + "Stacking " + str(fold_) + "-" * 10)
# #     cb_model = CatBoostRegressor(iterations=3000, learning_rate=0.1, depth=8, l2_leaf_reg=20, bootstrap_type='Bernoulli',  eval_metric='RMSE', metric_period=50, od_type='Iter', od_wait=45, random_seed=17, allow_writing_files=False)
# #     cb_model.fit(trn_data, trn_y, eval_set=(val_data, val_y), cat_features=[], use_best_model=True, verbose=True)
#     clf = Ridge(alpha=100)
#     clf.fit(trn_data, trn_y)
#
#     oof_stack[val_idx] = clf.predict(val_data)
#     predictions_stack += clf.predict(test_stack) / 300
#
#
# np.sqrt(mean_squared_error(y.values, oof_stack))
#
# predicted_stack = pd.DataFrame()
# predicted_stack['card_id'] = test['card_id']
# predicted_stack['target'] = predictions_stack
# predicted_stack[['card_id', 'target']] = predicted_stack[['card_id', 'target']]
# predicted_stack.to_csv(root + '/submission_stacked.csv', index=False)
# #predicted.to_csv(root + '/submission.csv', index=False,quoting=csv.QUOTE_NONNUMERIC)
#
# predicted_stack.head()

# %%
# %%time

model = XGBRegressor(colsample_bytree=0.8, gamma=0, 
                             learning_rate=0.03, max_depth=7, 
                             min_child_weight=4, n_estimators=650,#2200,
                             subsample=0.8, 
                             random_state =7, nthread = 16)

#pipeline = Pipeline([('imputer', Imputer(strategy='mean')),('standardscaler',StandardScaler(copy=True, with_mean=True, with_std=True)),('classify', model)])
pipeline = Pipeline([('classify', model)])
#pipeline = Pipeline([('imputer',Imputer(missing_values='NaN', strategy='mean', axis=0)),('standardscaler',StandardScaler(copy=True, with_mean=True, with_std=True)),('classify', model)])
pipeline.fit(X,y)
print('fit complete')
score = rmse_cv(pipeline, X, y)
print("\pipeline score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

preds = pipeline.predict(X_test)
print('prediction complete')
predicted = pd.DataFrame()
predicted['card_id'] = test['card_id']
predicted['target'] = preds
predicted[['card_id', 'target']] = predicted[['card_id', 'target']]
#predicted.to_csv(root + '/submission.csv', index=False,quoting=csv.QUOTE_NONNUMERIC)

predicted.head()
# Out:
# fit complete
# \pipeline score: 3.6687 (0.0299)
#
# prediction complete
# Wall time: 32min 34s

# %%
# %%time

import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sns
import csv
import re
import sys, os, random

from datetime import datetime

from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import PolynomialFeatures

from sklearn.model_selection import GridSearchCV

#sys.path.insert(0, "/Users/schwalmdaniel/github/xgboost/python-package")
sys.path.insert(0, "e:/xgboost/python-package")
from xgboost import XGBRegressor
import xgboost as xgb

from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
root = 'e:/kaggle/elo_merchant'
X=pd.read_csv(root + "/X.csv")
y=pd.read_csv(root + "/y.csv")
X_test=pd.read_csv(root + "/X_test.csv")


xgb1 = XGBRegressor()
parameters = {'nthread':[16], #when use hyperthread, xgboost may become slower
              'objective':['reg:linear'],
              'learning_rate': [.03], #so called `eta` value
              'max_depth': [4],
              'min_child_weight': [7],
              'subsample': [0.8],
              'colsample_bytree': [0.8],
              'n_estimators': [700,800,900],
             'gamma':[0] 
             }

xgb_grid = GridSearchCV(xgb1,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=10)

xgb_grid.fit(X,y)
print(xgb_grid.best_score_)
print(xgb_grid.best_params_)

# %% [raw]
# xgb1 = XGBRegressor()
# parameters = {'nthread':[8], #when use hyperthread, xgboost may become slower
#               'objective':['reg:linear'],
#               'learning_rate': [.03], #so called `eta` value
#               'max_depth': [5],
#               'min_child_weight': [7],
#               'silent': [1],
#               'subsample': [0.7],
#               'colsample_bytree': [0.7],
#               'n_estimators': [350,355,360,360,370],
#              'gamma':[0]
#              }
#
# xgb_grid = GridSearchCV(xgb1,
#                         parameters,
#                         cv = 2,
#                         n_jobs = 5,
#                         verbose=10)
#
# xgb_grid.fit(X,y)
# print(xgb_grid.best_score_)
# print(xgb_grid.best_params_)

# %%
str(list(_get_xgb_feat_importances(model, X.columns.tolist())))

# %%
plot_importance(model)
pyplot.show()

# %%
predicted.to_csv(root + '/submission.csv', index=False)

# %%
# blending

import seaborn as sns
from math import sqrt
from matplotlib import pyplot as plt

df_base1 = pd.read_csv(root +  '/submission_stacked.csv',names=["card_id","target1"], skiprows=[0],header=None)
df_base2 = pd.read_csv(root +  '/submission_ensemble_lgb_cb.csv',names=["card_id","target2"], skiprows=[0],header=None)
df_base3 = pd.read_csv(root +  '/submission_ensemble_lgb_xgb_cb.csv',names=["card_id","target3"], skiprows=[0],header=None)
df_base4 = pd.read_csv(root +  '/submission_cb.csv',names=["card_id","target4"], skiprows=[0],header=None)
df_base5 = pd.read_csv(root +  '/submission_lgbm.csv',names=["card_id","target5"], skiprows=[0],header=None)
df_base6 = pd.read_csv(root +  '/submission_ensemble_lgb_xgb.csv',names=["card_id","target6"], skiprows=[0],header=None)
df_base7 = pd.read_csv(root +  '/submission_ensemble_lgb_xgb2.csv',names=["card_id","target7"], skiprows=[0],header=None)
df_base8 = pd.read_csv(root +  '/submission_ensemble_cb_xgb.csv',names=["card_id","target8"], skiprows=[0],header=None)
df_base9 = pd.read_csv(root +  '/submission_ensemble_lgb_cb_xgb.csv',names=["card_id","target9"], skiprows=[0],header=None)
df_base10 = pd.read_csv(root +  '/submission_ensemble_cb_xgb.csv',names=["card_id","target10"], skiprows=[0],header=None)
df_base11 = pd.read_csv(root +  '/submission_ensemble.csv',names=["card_id","target11"], skiprows=[0],header=None)
df_base12 = pd.read_csv(root +  '/submission_xgb.csv',names=["card_id","target12"], skiprows=[0],header=None)

df_base = pd.merge(df_base1,df_base2,how='inner',on='card_id')

for df in [df_base3,df_base4,df_base5,df_base6,df_base7,df_base8,df_base8,df_base10,
          df_base11,df_base12]:
    df_base = pd.merge(df_base,df,how='inner',on='card_id')
    
plt.figure(figsize=(16,12))
sns.heatmap(df_base.iloc[:,1:].corr(),annot=True,fmt=".2f")

# %%
from sklearn import metrics
M = np.zeros([df_base.iloc[:,1:].shape[1],df_base.iloc[:,1:].shape[1]])
for i in np.arange(M.shape[1]):
    for j in np.arange(M.shape[1]):
        M[i,j] = sqrt(metrics.mean_squared_error(df_base.iloc[:,i+1], df_base.iloc[:,j+1]))
        
df_base['target'] = df_base.iloc[:,1:].mean(axis=1)
df_base[['card_id','target']].to_csv(root +  "/blending1.csv",index=False)
